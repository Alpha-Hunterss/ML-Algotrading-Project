# %% [markdown]
# <div class="alert alert-block alert-info">
#     <h2 align="center" style="color: black;">Alpha Hunters Algorithmic Trading Framework</h2>
#     <h3 align="center" style="color: black;">Data & Walk Forward Backtest Experiment Pipeline</h3>
# </div>

# %% [markdown]
# # Kaggle services and tools

# %%
# !pip install feature_engine
# !pip install colorlog
# Out:
# Collecting feature_engine
#   Downloading feature_engine-1.8.2-py2.py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: numpy>=1.18.2 in /usr/local/lib/python3.10/dist-packages (from feature_engine) (1.26.4)
# Requirement already satisfied: pandas>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from feature_engine) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from feature_engine) (1.5.2)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from feature_engine) (1.13.1)
# Requirement already satisfied: statsmodels>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from feature_engine) (0.14.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.2.0->feature_engine) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.2.0->feature_engine) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=2.2.0->feature_engine) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.0->feature_engine) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.4.0->feature_engine) (3.5.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.11.1->feature_engine) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.11.1->feature_engine) (24.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=2.2.0->feature_engine) (1.16.0)
# Downloading feature_engine-1.8.2-py2.py3-none-any.whl (374 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 375.0/375.0 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: feature_engine
# Successfully installed feature_engine-1.8.2
# Collecting colorlog
#   Downloading colorlog-6.9.0-py3-none-any.whl.metadata (10 kB)
# Downloading colorlog-6.9.0-py3-none-any.whl (11 kB)
# Installing collected packages: colorlog
# Successfully installed colorlog-6.9.0

# %%
# !pip show xgboost
# Out:
# Name: xgboost
# Version: 2.1.3
# Summary: XGBoost Python Package
# Home-page:
# Author:
# Author-email: Hyunsu Cho <chohyu01@cs.washington.edu>, Jiaming Yuan <jm.yuan@outlook.com>
# License: Apache-2.0
# Location: /usr/local/lib/python3.10/dist-packages
# Requires: numpy, nvidia-nccl-cu12, scipy
# Required-by:

# %%
model_type = 'XGB' #@param ['XGB', 'RF', 'LGBM'] {type: "string"}
MANUAL_EXP = True #@param {type:"boolean"}

# %%
print(MANUAL_EXP)
# Out:
# True

# %% [markdown]
# # Weights & Biase
#
# ![ChessUrl](https://docs.wandb.ai/assets/images/wandb_demo_experiments-4797af7fe7236d6c5c42adbdc93deb4c.gif "chess")
#
# Steps:
# - Create a W&B account [wandb.ai](https://wandb.ai/)
# - Read docs [W&B docs](https://docs.wandb.ai/)
# - Install using pip:  `!pip install wandb`
# - Get API token [link](https://wandb.ai/authorize)
# - Create a secret or an env variable for the token

# %%
import wandb
from google.colab import userdata
secret_value = userdata.get('wandb_token')
wandb.login(key=secret_value)

api = wandb.Api()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc

# %%
# !wandb login
# Out:
# wandb: Currently logged in as: amirhosseinfarahani (alpha-hunters). Use `wandb login --relogin` to force relogin

# %% [markdown]
# # Read functions from the GitHub repo
#
# - GitHub account and repo
# - Generate an access token on your GitHub account [Link](https://github.com/settings/tokens)
# - Then make a secret or an environment variable to use it

# %%
import sys
# %load_ext autoreload
# %reload_ext autoreload
# %autoreload 2
token = userdata.get("GITHUB_TOKEN")
branch_name = 'masoud' #@param ['main', 'masoud'] {type: "string"}
# !rm -r ./ML-Algotrading-Project
# !git clone -b {branch_name} https://{token}@github.com/AmirhsFar/ML-Algotrading-Project.git
# !pip install -r ./ML-Algotrading-Project/dataset/requirements.txt
sys.path.append("/content/ML-Algotrading-Project")
print('All done')
# Out:
# rm: cannot remove './ML-Algotrading-Project': No such file or directory
# Cloning into 'ML-Algotrading-Project'...
# remote: Enumerating objects: 625, done.
# remote: Counting objects: 100% (26/26), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 625 (delta 14), reused 16 (delta 7), pack-reused 599 (from 1)
# Receiving objects: 100% (625/625), 3.30 MiB | 9.28 MiB/s, done.
# Resolving deltas: 100% (441/441), done.
# Collecting aiohappyeyeballs==2.4.0 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 1))
#   Downloading aiohappyeyeballs-2.4.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiohttp==3.10.5 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 2))
#   Downloading aiohttp-3.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: aiosignal==1.3.1 in /usr/local/lib/python3.10/dist-packages (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 3)) (1.3.1)
# Collecting asttokens==2.4.1 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 4))
#   Downloading asttokens-2.4.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: attrs==24.2.0 in /usr/local/lib/python3.10/dist-packages (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 5)) (24.2.0)
# Collecting colorama==0.4.6 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 6))
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Collecting colorlog==6.8.2 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 7))
#   Downloading colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting comm==0.2.2 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 8))
#   Downloading comm-0.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting debugpy==1.8.5 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 9))
#   Downloading debugpy-1.8.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.1 kB)
# Collecting decorator==5.1.1 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 10))
#   Downloading decorator-5.1.1-py3-none-any.whl.metadata (4.0 kB)
# Collecting executing==2.1.0 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 11))
#   Downloading executing-2.1.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting frozenlist==1.4.1 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 12))
#   Downloading frozenlist-1.4.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting feature_engine==1.8.1 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 13))
#   Downloading feature_engine-1.8.1-py2.py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: idna==3.10 in /usr/local/lib/python3.10/dist-packages (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 14)) (3.10)
# Collecting ipykernel==6.29.5 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 15))
#   Downloading ipykernel-6.29.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting ipython==8.27.0 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 16))
#   Downloading ipython-8.27.0-py3-none-any.whl.metadata (5.0 kB)
# Collecting jedi==0.19.1 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 17))
#   Downloading jedi-0.19.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting jupyter_client==8.6.3 (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 18))
#   Downloading jupyter_client-8.6.3-py3-none-any.whl.metadata (8.3 kB)
# Requirement already satisfied: jupyter_core==5.7.2 in /usr/local/lib/python3.10/dist-packages (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 19)) (5.7.2)
# Requirement already satisfied: matplotlib-inline==0.1.7 in /usr/local/lib/python3.10/dist-packages (from -r ./ML-Algotrading-Project/dataset/requirements.txt (line 20)) (0.1.7)
# ERROR: Could not find a version that satisfies the requirement MetaTrader5==5.0.4424 (from versions: none)
# ERROR: No matching distribution found for MetaTrader5==5.0.4424
# All done

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

from dataset.configs.feature_configs_general import generate_general_config
from dataset.dukascopy_func import (
    crawl_OHLCV_data_dukascopy
)
from dataset.history_data_stage_one_func import (
    history_data_stage_one
)
from dataset.realtime_candle_func import (
    historiy_realtime_candle
)
from dataset.indicator_func import history_indicator_calculator
from dataset.realtime_shift_func import history_cndl_shift
from dataset.create_basic_features_func import (
    history_basic_features,
    history_fe_market_close,
    history_fe_time
)
from dataset.window_agg_features_func import (
    history_fe_WIN_features
)
from dataset.columns_merge_func import history_columns_merge
# from dataset.data_crawlers.metatrader_func import (
#     crawl_OHLCV_data_metatrader,
# )
from main_func import main
# from forex_MLOps.utils.wandb_utils import read_obj
from ETL import read_data_manual, ETL
# from forex_MLOps.model_ensemble import QuantEnsemble
from utils.wandb_utils import (
    fetch_artifacts, read_tracker_objects, download_wandb_artifact
)
########### READ DATA MANUALLY #########
# df_all = read_data_manual()
# !tail -n 120 ./forex_MLOps/ETL.py

# %% [markdown]
# # 0. Data Fetching & Preprocessing

# %% [markdown]
# ## Dukascopy

# %%
config_general = generate_general_config()
failed_dates_dict = await crawl_OHLCV_data_dukascopy(
    feature_config = config_general
)
# Out:
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> start crawl_OHLCV_data_dukascopy fumc:
# INFO:test run:--> start crawl_OHLCV_data_dukascopy fumc:
#   [test run][INFO]:--> number of days ALL in time range: 708
# INFO:test run:--> number of days ALL in time range: 708
#   [test run][INFO]:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-12-08 00:00:00
# INFO:test run:--> start_date: 2023-01-01 00:00:00 , stop_date: 2024-12-08 00:00:00
#   [test run][INFO]:==============================
# INFO:test run:==============================
#   [test run][INFO]:--> EURUSD
# INFO:test run:--> EURUSD
#   [test run][INFO]:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/11/08/BID_candles_min_1.bi5
# INFO:test run:--> faild_date: https://datafeed.dukascopy.com/datafeed/EURUSD/2024/11/08/BID_candles_min_1.bi5
#   [test run][INFO]:--> df.shape: (1018080, 6)
# INFO:test run:--> df.shape: (1018080, 6)
#   [test run][INFO]:--> faild_dates: [datetime.datetime(2024, 12, 8, 0, 0, tzinfo=datetime.timezone.utc)]
# INFO:test run:--> faild_dates: [datetime.datetime(2024, 12, 8, 0, 0, tzinfo=datetime.timezone.utc)]
#   [test run][INFO]:--> fEURUSD run-time: 147.39 seconds
# INFO:test run:--> fEURUSD run-time: 147.39 seconds
#   [test run][INFO]:--> crawl_OHLCV_data_dukascopy successfully.
# INFO:test run:--> crawl_OHLCV_data_dukascopy successfully.

# %%
import pandas as pd

pd.set_option('display.max_columns', None)
df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/raw_data/dukascopy/EURUSD_dukascopy.parquet"
)
df.iloc[[1000, 1006, 11012]]
# Out:
#                           _time     open     high      low    close  \
# 1000  2023-01-04 11:20:00+00:00  1.06179  1.06188  1.06151  1.06173
# 1006  2023-01-04 11:50:00+00:00  1.06038  1.06079  1.06021  1.06063
# 11012 2023-02-08 05:40:00+00:00  1.07294  1.07295  1.07280  1.07290
#
#        tick_volume data_source  symbol
# 1000    671.040009   dukascopy  EURUSD
# 1006    665.929993   dukascopy  EURUSD
# 11012   207.729996   dukascopy  EURUSD

# %% [markdown]
# ## Metatrader 5
#
# Do this section in your system and place the `.parquet` file in *dataset\data\raw_data\metatrader*, then reclone the repository and proceed for the furthur steps.

# %% [markdown]
# ## Creating Stage-One Data

# %%
history_data_stage_one(config_general)
# Out:
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = =
# INFO:test run:= = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:--> start history_data_stage_one fumc:
# INFO:test run:--> start history_data_stage_one fumc:
#   [test run][INFO]:-------------------------
# INFO:test run:-------------------------
#   [test run][INFO]:--> symbol:EURUSD
# INFO:test run:--> symbol:EURUSD
#   [test run][INFO]:--> number of nulls before forward fill: 0
# INFO:test run:--> number of nulls before forward fill: 0
#   [test run][INFO]:--> min time: 2023-01-03 00:00:00, max time: 2024-12-06 23:55:00
# INFO:test run:--> min time: 2023-01-03 00:00:00, max time: 2024-12-06 23:55:00
#   [test run][INFO]:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
# INFO:test run:--> parquet saved. /content/ML-Algotrading-Project/dataset//data/stage_one_data//EURUSD_stage_one.parquet
#   [test run][INFO]:--> history_data_stage_one run successfully.
# INFO:test run:--> history_data_stage_one run successfully.

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/stage_one_data/EURUSD_stage_one.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 120000]]
# Out:
#                      _time     open     high      low    close  tick_volume  \
# 1      2023-01-03 00:05:00  1.06648  1.06650  1.06646  1.06650    15.320000
# 5      2023-01-03 00:25:00  1.06652  1.06652  1.06649  1.06652    10.800000
# 1000   2023-01-06 11:20:00  1.05131  1.05133  1.04965  1.05060  2732.000031
# 2006   2023-01-11 23:10:00  1.07557  1.07557  1.07542  1.07550   399.619991
# 11012  2023-02-24 05:40:00  1.06029  1.06030  1.06015  1.06015   494.959991
# 120000 2024-08-07 16:00:00  1.09215  1.09224  1.09181  1.09197   465.000000
#
#        data_source  was_ffilled       _date
# 1        dukascopy        False  2023-01-03
# 5        dukascopy        False  2023-01-03
# 1000     dukascopy        False  2023-01-06
# 2006     dukascopy        False  2023-01-11
# 11012    dukascopy        False  2023-02-24
# 120000  metatrader        False  2024-08-07

# %% [markdown]
# ## Creating Real-Time Candles

# %%
historiy_realtime_candle(config_general)
# Out:
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> start historiy_realtime_candle fumc:
# INFO:test run:--> start historiy_realtime_candle fumc:
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
# INFO:test run:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:symbol: EURUSD
# INFO:test run:symbol: EURUSD
#   [test run][INFO]:--> EURUSD saved.
# INFO:test run:--> EURUSD saved.
#   [test run][INFO]:--> historiy_realtime_candle run successfully.
# INFO:test run:--> historiy_realtime_candle run successfully.

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/realtime_candle/EURUSD_realtime_candle.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000]]
# Out:
#                     _time  index  M5_OPEN  M5_CLOSE   M5_LOW  M5_HIGH  \
# 1     2023-01-03 00:05:00      1  1.06648   1.06650  1.06646  1.06650
# 5     2023-01-03 00:25:00      5  1.06652   1.06652  1.06649  1.06652
# 1000  2023-01-06 11:20:00   1000  1.05131   1.05060  1.04965  1.05133
# 2006  2023-01-11 23:10:00   2006  1.07557   1.07550  1.07542  1.07557
# 11012 2023-02-24 05:40:00  11012  1.06029   1.06015  1.06015  1.06030
# 20000 2023-04-10 10:40:00  20000  1.09085   1.09088  1.09079  1.09094
#
#          M5_VOLUME       _date  minutesPassed  isFirst  M15_OPEN  M15_HIGH  \
# 1        15.320000  2023-01-03              5        0   1.06646   1.06650
# 5        10.800000  2023-01-03             25        0   1.06651   1.06653
# 1000   2732.000031  2023-01-06            680        0   1.05152   1.05172
# 2006    399.619991  2023-01-11           1390        0   1.07537   1.07557
# 11012   494.959991  2023-02-24            340        0   1.06040   1.06051
# 20000   510.120010  2023-04-10            640        0   1.09073   1.09094
#
#        M15_LOW  M15_CLOSE   M15_VOLUME  M30_OPEN  M30_HIGH  M30_LOW  \
# 1      1.06645    1.06650    49.620001   1.06646   1.06650  1.06645
# 5      1.06648    1.06652    21.140000   1.06646   1.06653  1.06645
# 1000   1.04965    1.05060  4264.860046   1.05182   1.05193  1.04965
# 2006   1.07518    1.07550  1465.669991   1.07537   1.07557  1.07518
# 5    1.06646    1.06653   1.06645     1.06652    77.270000    1.06646
# 6    1.06646    1.06653   1.06645     1.06648   132.899999    1.06646
# 7    1.06646    1.06653   1.06645     1.06645   175.959999    1.06646
# 8    1.06646    1.06653   1.06636     1.06640   243.659998    1.06646
# 9    1.06646    1.06653   1.06636     1.06637   285.959998    1.06646
#
#    M720_HIGH  M720_LOW  M720_CLOSE  M720_VOLUME  M1440_OPEN  M1440_HIGH  \
# 0    1.06649   1.06645     1.06648    34.300000     1.06646     1.06649
# 1    1.06650   1.06645     1.06650    49.620001     1.06646     1.06650
# 2    1.06651   1.06645     1.06651    56.130001     1.06646     1.06651
# 3    1.06653   1.06645     1.06653    65.570001     1.06646     1.06653
# 4    1.06653   1.06645     1.06652    66.470001     1.06646     1.06653
# 5    1.06653   1.06645     1.06652    77.270000     1.06646     1.06653
# 6    1.06653   1.06645     1.06648   132.899999     1.06646     1.06653
# 7    1.06653   1.06645     1.06645   175.959999     1.06646     1.06653
# 8    1.06653   1.06636     1.06640   243.659998     1.06646     1.06653
# 9    1.06653   1.06636     1.06637   285.959998     1.06646     1.06653
#
#    M1440_LOW  M1440_CLOSE  M1440_VOLUME  symbol
# 0    1.06645      1.06648     34.300000  EURUSD
# 1    1.06645      1.06650     49.620001  EURUSD
# 2    1.06645      1.06651     56.130001  EURUSD
# 3    1.06645      1.06653     65.570001  EURUSD
# 4    1.06645      1.06652     66.470001  EURUSD
# 5    1.06645      1.06652     77.270000  EURUSD
# 6    1.06645      1.06648    132.899999  EURUSD
# 7    1.06645      1.06645    175.959999  EURUSD
# 8    1.06636      1.06640    243.659998  EURUSD
# 9    1.06636      1.06637    285.959998  EURUSD

# %% [markdown]
# ## Adding Features

# %% [markdown]
# ### A) Indicators

# %%
history_indicator_calculator(config_general)
# Out:
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> start history_indicator_calculator fumc:
# INFO:test run:--> start history_indicator_calculator fumc:
#   [test run][INFO]:* * * * * * * * * * * * * * * * * * * * * * * * *
# INFO:test run:* * * * * * * * * * * * * * * * * * * * * * * * *
#   [test run][INFO]:--------------------------------------------------
# INFO:test run:--------------------------------------------------
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSI
# INFO:test run:--> symbol:EURUSD | fe_prefix:fe_RSI
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
# INFO:test run:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> fe_RSI_EURUSD done.
# INFO:test run:--> fe_RSI_EURUSD done.
#   [test run][INFO]:--------------------------------------------------
# INFO:test run:--------------------------------------------------
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_EMA
# INFO:test run:--> symbol:EURUSD | fe_prefix:fe_EMA
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:1440| drop_rows:1440.0
# INFO:test run:--> max_candle_timeframe:5 | max_window_size:1440| drop_rows:1440.0
#   [test run][INFO]:--> fe_EMA_EURUSD done.
# INFO:test run:--> fe_EMA_EURUSD done.
#   [test run][INFO]:--------------------------------------------------
# INFO:test run:--------------------------------------------------
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_SMA
# INFO:test run:--> symbol:EURUSD | fe_prefix:fe_SMA
#   [test run][INFO]:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
# INFO:test run:--> max_candle_timeframe:5 | max_window_size:720| drop_rows:720.0
#   [test run][INFO]:--> fe_SMA_EURUSD done.
# INFO:test run:--> fe_SMA_EURUSD done.
#   [test run][INFO]:--------------------------------------------------
# INFO:test run:--------------------------------------------------
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_ATR
# INFO:test run:--> symbol:EURUSD | fe_prefix:fe_ATR
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
# INFO:test run:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> fe_ATR_EURUSD done.
# INFO:test run:--> fe_ATR_EURUSD done.
#   [test run][INFO]:--------------------------------------------------
# INFO:test run:--------------------------------------------------
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_RSTD
# INFO:test run:--> symbol:EURUSD | fe_prefix:fe_RSTD
#   [test run][INFO]:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
# INFO:test run:--> max_candle_timeframe:240 | max_window_size:30| drop_rows:1487.0
#   [test run][INFO]:--> fe_RSTD_EURUSD done.
# INFO:test run:--> fe_RSTD_EURUSD done.
#   [test run][INFO]:--------------------------------------------------
# INFO:test run:--------------------------------------------------
#   [test run][INFO]:--> symbol:EURUSD | fe_prefix:fe_cndl_shape_n_cntxt
# INFO:test run:--> symbol:EURUSD | fe_prefix:fe_cndl_shape_n_cntxt
#   [test run][INFO]:--> max_candle_timeframe:60 | max_window_size:12| drop_rows:155.0
# INFO:test run:--> max_candle_timeframe:60 | max_window_size:12| drop_rows:155.0
#   [test run][INFO]:--> fe_cndl_shape_n_cntxt_EURUSD done.
# INFO:test run:--> fe_cndl_shape_n_cntxt_EURUSD done.
#   [test run][INFO]:--> fe_ratio_EURUSD saved.
# INFO:test run:--> fe_ratio_EURUSD saved.
#   [test run][INFO]:--> history_indicator_calculator run successfully.
# INFO:test run:--> history_indicator_calculator run successfully.

# %% [markdown]
# **Candle Shape**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_cndl_shape/fe_cndl_shape_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000]]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-7bbdca436af8> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_parquet(
#       4     f"/content/ML-Algotrading-Project/dataset/data/features/fe_cndl_shape/fe_cndl_shape_EURUSD.parquet"
#       5 )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     665     check_dtype_backend(dtype_backend)
#     666
# --> 667     return impl.read(
#     668         path,
#     669         columns=columns,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
#     265             to_pandas_kwargs["split_blocks"] = True  # type: ignore[assignment]
#     266
# --> 267         path_or_handle, handles, filesystem = _get_path_or_handle(
#     268             path,
#     269             filesystem,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in _get_path_or_handle(path, fs, storage_options, mode, is_dir)
#     138         # fsspec resources can also point to directories
#     139         # this branch is used for example when reading from non-fsspec URLs
# --> 140         handles = get_handle(
#     141             path_or_handle, mode, is_text=False, storage_options=storage_options
#     142         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     880         else:
#     881             # Binary mode
# --> 882             handle = open(handle, ioargs.mode)
#     883         handles.append(handle)
#     884
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/ML-Algotrading-Project/dataset/data/features/fe_cndl_shape/fe_cndl_shape_EURUSD.parquet'

# %% [markdown]
# **ATR**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_ATR/fe_ATR_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000]]
# Out:
#                     _time  fe_ATR_W7_M240  fe_ATR_W30_M60  fe_ATR_W14_M60  \
# 1     2023-01-10 04:00:00       36.228571       16.616667       18.071429
# 5     2023-01-10 04:20:00       36.228571       16.616667       18.071429
# 1000  2023-01-13 15:15:00       48.885714       22.896667       17.428571
# 2006  2023-01-19 03:05:00       47.628571       19.860000       22.407143
# 11012 2023-03-03 09:35:00       27.985714       13.646667       10.450000
# 20000 2023-04-17 14:35:00       35.128571       14.980000       12.542857
#
#        fe_ATR_W7_M60  fe_ATR_W14_M240  fe_ATR_W30_M240  symbol
# 1          12.600000        40.957143        43.633333  EURUSD
# 5          12.600000        40.957143        43.633333  EURUSD
# 1000       21.600000        38.900000        39.236667  EURUSD
# 2006        8.928571        41.635714        42.166667  EURUSD
# 11012       9.500000        31.221429        30.186667  EURUSD
# 20000      15.057143        31.078571        29.563333  EURUSD

# %% [markdown]
# **RSTD**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_RSTD/fe_RSTD_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000]]
# Out:
#                     _time  fe_RSTD_M240_CLOSE_W14_cndl_M240  \
# 1     2023-01-10 04:00:00                         28.851866
# 5     2023-01-10 04:20:00                         28.851866
# 1000  2023-01-13 15:15:00                         17.349237
# 2006  2023-01-19 03:05:00                         33.624757
# 11012 2023-03-03 09:35:00                         20.490879
# 20000 2023-04-17 14:35:00                         21.546791
#
#        fe_RSTD_M240_CLOSE_W7_cndl_M240  fe_RSTD_M240_CLOSE_W30_cndl_M240  \
# 1                            22.196076                         33.800598
# 5                            22.196076                         33.800598
# 1000                         23.693676                         22.990681
# 2006                         42.221738                         29.125541
# 11012                        17.424743                         19.887670
# 20000                        22.011785                         21.233008
#
#        symbol
# 1      EURUSD
# 5      EURUSD
# 1000   EURUSD
# 2006   EURUSD
# 11012  EURUSD
# 20000  EURUSD

# %% [markdown]
# **ratio**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_ratio/fe_ratio_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000]]
# Out:
#                     _time  fe_ratio_RSI_M5_CLOSE_W7_W14_cndl_M5  \
# 1     2023-01-10 04:00:00                               1.10364
# 5     2023-01-10 04:20:00                               1.07202
# 1000  2023-01-13 15:15:00                               1.21804
# 2006  2023-01-19 03:05:00                               1.07378
# 11012 2023-03-03 09:35:00                               0.92585
# 20000 2023-04-17 14:35:00                               0.71864
#
#        fe_ratio_RSI_M5_CLOSE_W7_W30_cndl_M5  \
# 1                                   1.24858
# 5                                   1.22618
# 1000                                1.29301
# 2006                                1.13642
# 11012                               0.89426
# 20000                               0.64987
#
#        fe_ratio_RSI_M60_CLOSE_W7_W14_cndl_M60  \
# 1                                     0.92447
# 5                                     0.92447
# 1000                                  0.66147
# 2006                                  0.85202
# 11012                                 1.24219
# 20000                                 1.09720
#
#        fe_ratio_RSI_M60_CLOSE_W7_W30_cndl_M60  \
# 1                                     0.93830
# 5                                     0.93830
# 1000                                  0.56106
# 2006                                  0.78994
# 11012                                 1.32987
# 20000                                 1.02517
#
#        fe_ratio_RSI_M240_CLOSE_W7_W14_cndl_M240  \
# 1                                       1.09920
# 5                                       1.09920
# 1000                                    1.01861
# 2006                                    0.90326
# 11012                                   0.97893
# 20000                                   0.77015
#
#        fe_ratio_RSI_M240_CLOSE_W7_W30_cndl_M240  \
# 1                                       1.21066
# 5                                       1.21066
# 1000                                    1.10077
# 2006                                    0.82459
# 11012                                   1.00778
# 20000                                   0.68171
#
#        fe_ratio_EMA_M5_CLOSE_W7_W60_cndl_M5  \
# 1                                   0.18333
# 5                                   0.21334
# 1000                               -0.09465
# 2006                               -9.42515
# 11012                              -0.04950
# 20000                               0.36801
#
#        fe_ratio_EMA_M5_CLOSE_W60_W336_cndl_M5  \
# 1                                     0.08811
# 5                                     0.15171
# 1000                                  1.26029
# 2006                                  0.02088
# 11012                                 1.20735
# 20000                                 0.25329
#
#        fe_ratio_EMA_M5_CLOSE_W60_W1440_cndl_M5  \
# 1                                      0.03184
# 5                                      0.05710
# 1000                                  -0.22112
# 2006                                   0.05142
# 11012                                  3.04681
# 20000                                  1.39218
#
#        fe_ratio_SMA_M5_CLOSE_W240_W720_cndl_M5  \
# 1                                      0.16447
# 5                                      0.18357
# 1000                                  -1.22493
# 2006                                   1.12334
# 11012                                 -2.85007
# 20000                                  0.22549
#
#        fe_ratio_SMA_M5_CLOSE_W360_W720_cndl_M5  \
# 1                                      0.32427
# 5                                      0.33907
# 1000                                  -0.36034
# 2006                                   0.62363
# 11012                                 -0.56173
# 20000                                  0.69338
#
#        fe_ratio_ATR_M60_CLOSE_W7_W14_cndl_M60  \
# 1                                     0.69723
# 5                                     0.69723
# 1000                                  1.23934
# 2006                                  0.39847
# 11012                                 0.90909
# 20000                                 1.20046
#
#        fe_ratio_ATR_M60_CLOSE_W7_W30_cndl_M60  \
# 1                                     0.75827
# 5                                     0.75827
# 1000                                  0.94337
# 2006                                  0.44958
# 11012                                 0.69614
# 20000                                 1.00515
#
#        fe_ratio_ATR_M240_CLOSE_W7_W14_cndl_M240  \
# 1                                       0.88455
# 5                                       0.88455
# 1000                                    1.25670
# 2006                                    1.14394
# 11012                                   0.89636
# 20000                                   1.13031
#
#        fe_ratio_ATR_M240_CLOSE_W7_W30_cndl_M240  \
# 1                                       0.83030
# 5                                       0.83030
# 1000                                    1.24592
# 2006                                    1.12953
# 11012                                   0.92709
# 20000                                   1.18825
#
#        fe_ratio_RSTD_M240_CLOSE_W7_W14_cndl_M240  \
# 1                                        0.76931
# 5                                        0.76931
# 1000                                     1.36569
# 2006                                     1.25567
# 11012                                    0.85037
# 20000                                    1.02158
#
#        fe_ratio_RSTD_M240_CLOSE_W7_W30_cndl_M240  symbol
# 1                                        0.65668  EURUSD
# 5                                        0.65668  EURUSD
# 1000                                     1.03058  EURUSD
# 2006                                     1.44965  EURUSD
# 11012                                    0.87616  EURUSD
# 20000                                    1.03668  EURUSD

# %% [markdown]
# **SMA**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_SMA/fe_SMA_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000]]
# Out:
#                     _time  fe_SMA_M5_CLOSE_W360_cndl_M5_norm  \
# 1     2023-01-05 12:05:00                         -11.809722
# 5     2023-01-05 12:25:00                         -11.435833
# 1000  2023-01-10 23:20:00                          -1.176389
# 2006  2023-01-16 11:10:00                          26.924722
# 11012 2023-02-28 17:40:00                         -27.663056
# 20000 2023-04-12 22:40:00                         -54.114167
#
#        fe_SMA_M5_CLOSE_W720_cndl_M5_norm  fe_SMA_M5_CLOSE_W240_cndl_M5_norm  \
# 1                             -19.095972                          -7.779167
# 5                             -19.553472                          -7.900417
# 1000                          -51.889861                          -2.746667
# 2006                            7.948056                          25.888333
# 11012                         -45.524028                         -19.715417
# 20000                         -81.302361                         -42.127917
#
#        symbol
# 1      EURUSD
# 5      EURUSD
# 1000   EURUSD
# 2006   EURUSD
# 11012  EURUSD
# 20000  EURUSD

# %% [markdown]
# **RSI**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_RSI/fe_RSI_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000]]
# Out:
#                     _time  fe_RSI_M240_CLOSE_W30_cndl_M240  \
# 1     2023-01-10 04:00:00                        62.347311
# 5     2023-01-10 04:20:00                        62.347311
# 1000  2023-01-13 15:15:00                        67.966007
# 2006  2023-01-19 03:05:00                        52.709877
# 11012 2023-03-03 09:35:00                        47.784069
# 20000 2023-04-17 14:35:00                        52.447879
#
#        fe_RSI_M240_CLOSE_W30_gte_70_cndl_M240  \
# 1                                       False
# 5                                       False
# 1000                                    False
# 2006                                    False
# 11012                                   False
# 20000                                   False
#
#        fe_RSI_M240_CLOSE_W30_lte_30_cndl_M240  fe_RSI_M60_CLOSE_W14_cndl_M60  \
# 1                                       False                      64.267715
# 5                                       False                      64.267715
# 1000                                    False                      44.888632
# 2006                                    False                      42.979763
# 11012                                   False                      54.838257
# 20000                                   False                      42.936395
#
#        fe_RSI_M60_CLOSE_W14_gte_70_cndl_M60  \
# 1                                     False
# 5                                     False
# 1000                                  False
# 2006                                  False
# 11012                                 False
# 20000                                 False
#
#        fe_RSI_M60_CLOSE_W14_lte_30_cndl_M60  fe_RSI_M5_CLOSE_W14_cndl_M5  \
# 1                                     False                    60.715630
# 5                                     False                    64.806664
# 1000                                  False                    43.942078
# 2006                                  False                    52.712556
# 11012                                 False                    55.000955
# 20000                                 False                    40.670144
#
#        fe_RSI_M5_CLOSE_W14_gte_70_cndl_M5  fe_RSI_M5_CLOSE_W14_lte_30_cndl_M5  \
# 1                                   False                               False
# 5                                   False                               False
# 1000                                False                               False
# 2006                                False                               False
# 11012                               False                               False
# 20000                               False                               False
#
#        fe_RSI_M240_CLOSE_W14_cndl_M240  \
# 1                            68.669294
# 5                            68.669294
# 1000                         73.448419
# 2006                         48.118779
# 11012                        49.192361
# 20000                        46.425033
#
#        fe_RSI_M240_CLOSE_W14_gte_70_cndl_M240  \
# 1                                       False
# 5                                       False
# 1000                                     True
# 2006                                    False
# 11012                                   False
# 20000                                   False
#
#        fe_RSI_M240_CLOSE_W14_lte_30_cndl_M240  fe_RSI_M5_CLOSE_W30_cndl_M5  \
# 1                                       False                    53.667595
# 5                                       False                    56.658967
# 1000                                    False                    41.394286
# 2006                                    False                    49.807106
# 11012                                   False                    56.943621
# 20000                                   False                    44.974307
#
#        fe_RSI_M5_CLOSE_W30_gte_70_cndl_M5  fe_RSI_M5_CLOSE_W30_lte_30_cndl_M5  \
# 1                                   False                               False
# 5                                   False                               False
# 1000                                False                               False
# 2006                                False                               False
# 11012                               False                               False
# 20000                               False                               False
#
#        fe_RSI_M240_CLOSE_W7_cndl_M240  fe_RSI_M240_CLOSE_W7_gte_70_cndl_M240  \
# 1                           75.481220                                   True
# 5                           75.481220                                   True
# 1000                        74.815001                                   True
# 2006                        43.463978                                  False
# 11012                       48.155659                                  False
# 20000                       35.754040                                  False
#
#        fe_RSI_M240_CLOSE_W7_lte_30_cndl_M240  fe_RSI_M5_CLOSE_W7_cndl_M5  \
# 1                                      False                   67.008366
# 5                                      False                   69.474144
# 1000                                   False                   53.523362
# 2006                                   False                   56.601702
# 11012                                  False                   50.922419
# 20000                                  False                   29.227274
#
#        fe_RSI_M5_CLOSE_W7_gte_70_cndl_M5  fe_RSI_M5_CLOSE_W7_lte_30_cndl_M5  \
# 1                                  False                              False
# 5                                  False                              False
# 1000                               False                              False
# 2006                               False                              False
# 11012                              False                              False
# 20000                              False                               True
#
#        fe_RSI_M60_CLOSE_W30_cndl_M60  fe_RSI_M60_CLOSE_W30_gte_70_cndl_M60  \
# 1                          63.320560                                 False
# 5                          63.320560                                 False
# 1000                       52.922225                                 False
# 2006                       46.357422                                 False
# 11012                      51.222783                                 False
# 20000                      45.953516                                 False
#
#        fe_RSI_M60_CLOSE_W30_lte_30_cndl_M60  fe_RSI_M60_CLOSE_W7_cndl_M60  \
# 1                                     False                     59.413433
# 5                                     False                     59.413433
# 1000                                  False                     29.692562
# 2006                                  False                     36.619519
# 11012                                 False                     68.119519
# 20000                                 False                     47.109967
#
#        fe_RSI_M60_CLOSE_W7_gte_70_cndl_M60  \
# 1                                    False
# 5                                    False
# 1000                                 False
# 2006                                 False
# 11012                                False
# 20000                                False
#
#        fe_RSI_M60_CLOSE_W7_lte_30_cndl_M60  symbol
# 1                                    False  EURUSD
# 5                                    False  EURUSD
# 1000                                  True  EURUSD
# 2006                                 False  EURUSD
# 11012                                False  EURUSD
# 20000                                False  EURUSD

# %% [markdown]
# **EMA**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_EMA/fe_EMA_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000]]
# Out:
#                     _time  fe_EMA_M5_CLOSE_W336_cndl_M5_norm  \
# 1     2023-01-10 00:05:00                         -42.736681
# 5     2023-01-10 00:25:00                         -42.623860
# 1000  2023-01-13 11:20:00                         -21.160687
# 2006  2023-01-18 23:10:00                          24.182541
# 11012 2023-03-03 05:40:00                           8.033484
# 20000 2023-04-17 10:40:00                          10.546297
#
#        fe_EMA_M5_CLOSE_W1440_cndl_M5_norm  fe_EMA_M5_CLOSE_W60_cndl_M5_norm  \
# 1                             -107.465487                          7.880523
# 5                             -107.675895                          6.035760
# 1000                           -96.001273                          3.594805
# 2006                            11.177333                         10.916314
# 11012                           10.969361                         -0.855511
# 20000                          -13.377422                         -4.449499
#
#        fe_EMA_M5_CLOSE_W7_cndl_M5_norm  symbol
# 1                             1.143644  EURUSD
# 5                            -0.256894  EURUSD
# 1000                          8.072713  EURUSD
# 2006                          1.148326  EURUSD
# 11012                        -0.150666  EURUSD
# 20000                         2.481712  EURUSD

# %% [markdown]
# ### B) Shift Features

# %%
history_cndl_shift(config_general)
# Out:
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
# INFO:test run:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:--> start history_cndl_shift fumc:
# INFO:test run:--> start history_cndl_shift fumc:
#   [test run][INFO]:-  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
# INFO:test run:-  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -  -
#   [test run][INFO]:--> fe_cndl_shift | EURUSD saved.
# INFO:test run:--> fe_cndl_shift | EURUSD saved.
#   [test run][INFO]:--> history_cndl_shift run successfully.
# INFO:test run:--> history_cndl_shift run successfully.

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_cndl_shift_raw/fe_cndl_shift_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000, 35000, 70000, 120000]]
# Out:
#                      _time  M5_OPEN_-1  M5_HIGH_-1  M5_LOW_-1  M5_CLOSE_-1  \
# 1      2023-01-03 00:05:00     1.06646     1.06649    1.06645      1.06648
# 5      2023-01-03 00:25:00     1.06653     1.06653    1.06652      1.06652
# 1000   2023-01-06 11:20:00     1.05152     1.05172    1.05124      1.05130
# 2006   2023-01-11 23:10:00     1.07549     1.07556    1.07535      1.07556
# 11012  2023-02-24 05:40:00     1.06041     1.06046    1.06022      1.06028
config_general)
# Out:
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> start history_basic_features fumc:
# INFO:test run:--> start history_basic_features fumc:
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> fe_cndl, EURUSD:
# INFO:test run:--> fe_cndl, EURUSD:
#   [test run][INFO]:--> fe_cndl EURUSD saved.
# INFO:test run:--> fe_cndl EURUSD saved.
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> fe_cndl_shift, EURUSD :
# INFO:test run:--> fe_cndl_shift, EURUSD :
#   [test run][INFO]:--> fe_cndl_shift_stage_2 EURUSD saved.
# INFO:test run:--> fe_cndl_shift_stage_2 EURUSD saved.
#   [test run][INFO]:--> history_basic_features run successfully.
# INFO:test run:--> history_basic_features run successfully.
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> start history_fe_market_close fumc:
# INFO:test run:--> start history_fe_market_close fumc:
#   [test run][INFO]:-->EURUSD
# INFO:test run:-->EURUSD
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
# INFO:test run:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:--> history_fe_market_close run successfully.
# INFO:test run:--> history_fe_market_close run successfully.
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> start history_fe_time fumc:
# INFO:test run:--> start history_fe_time fumc:
#   [test run][INFO]:--> history_fe_time run successfully.
# INFO:test run:--> history_fe_time run successfully.

# %% [markdown]
# **Candle Shift**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_cndl_shift/fe_cndl_shift_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000, 35000, 70000, 120000]]
# Out:
#                      _time  fe_cndl_shift_M5_CLOSE_to_OPEN_-1  \
# 1      2023-01-03 00:05:00                            0.00002
# 5      2023-01-03 00:25:00                           -0.00001
# 1000   2023-01-06 11:20:00                           -0.00022
# 2006   2023-01-11 23:10:00                            0.00007
# 11012  2023-02-24 05:40:00                           -0.00013
# 20000  2023-04-10 10:40:00                            0.00018
# 35000  2023-06-21 12:40:00                           -0.00022
# 70000  2023-12-08 01:20:00                           -0.00012
# 120000 2024-08-07 16:00:00                            0.00027
#
#         fe_cndl_shift_M5_HIGH_to_LOW_-1  fe_cndl_shift_M5_HIGH_to_CLOSE_-1  \
# 1                               0.00004                            0.00001
# 5                               0.00001                            0.00001
# 1000                            0.00048                            0.00042
# 2006                            0.00021                            0.00000
# 11012                           0.00024                            0.00018
# 20000                           0.00021                            0.00003
# 35000                           0.00048                            0.00031
# 70000                           0.00013                            0.00013
# 120000                          0.00032                            0.00005
#
#         fe_cndl_shift_M5_HIGH_to_OPEN_-1  fe_cndl_shift_M5_OPEN_to_LOW_-1  \
# 1                                0.00003                          0.00001
# 5                                0.00000                          0.00001
# 1000                             0.00020                          0.00028
# 2006                             0.00007                          0.00014
# 11012                            0.00005                          0.00019
# 20000                            0.00021                          0.00000
# 35000                            0.00009                          0.00039
# 70000                            0.00001                          0.00012
# 120000                           0.00032                          0.00000
#
#         fe_cndl_shift_M5_CLOSE_to_LOW_-1  fe_cndl_shift_M15_CLOSE_to_OPEN_-1  \
# 1                                0.00003                             0.00002
# 5                                0.00000                             0.00005
# 1000                             0.00006                            -0.00032
# 2006                             0.00021                            -0.00039
# 11012                            0.00006                            -0.00002
# 20000                            0.00018                            -0.00013
# 35000                            0.00017                             0.00093
# 70000                            0.00000                            -0.00003
# 120000                           0.00027                             0.00057
#
#         fe_cndl_shift_M15_HIGH_to_LOW_-1  fe_cndl_shift_M15_HIGH_to_CLOSE_-1  \
# 1                                0.00004                             0.00001
# 5                                0.00006                             0.00000
# 1000                             0.00048                             0.00043
# 2006                             0.00066                             0.00052
# 11012                            0.00025                             0.00012
# 20000                            0.00045                             0.00044
# 35000                            0.00095                             0.00000
# 70000                            0.00047                             0.00046
# 120000                           0.00064                             0.00005
#
# 1000                              0.00074
# 2006                              0.00014
# 11012                             0.00023
# 20000                             0.00096
# 35000                             0.00155
# 70000                             0.00033
# 120000                            0.00084
#
#         fe_cndl_shift_M240_CLOSE_to_OPEN_-1  \
# 1                                   0.00002
# 5                                   0.00002
# 1000                               -0.00108
# 2006                               -0.00033
# 11012                               0.00076
# 20000                              -0.00072
# 35000                               0.00087
# 70000                              -0.00203
# 120000                              0.00031
#
#         fe_cndl_shift_M240_HIGH_to_LOW_-1  \
# 1                                 0.00004
# 5                                 0.00004
# 1000                              0.00258
# 2006                              0.00400
# 11012                             0.00214
# 20000                             0.00115
# 35000                             0.00278
# 70000                             0.00231
# 120000                            0.00181
#
#         fe_cndl_shift_M240_HIGH_to_CLOSE_-1  \
# 1                                   0.00001
# 5                                   0.00001
# 1000                                0.00221
# 2006                                0.00297
# 11012                               0.00131
# 20000                               0.00104
# 35000                               0.00088
# 70000                               0.00204
# 120000                              0.00047
#
#         fe_cndl_shift_M240_HIGH_to_OPEN_-1  fe_cndl_shift_M240_OPEN_to_LOW_-1  \
# 1                                  0.00003                            0.00001
# 5                                  0.00003                            0.00001
# 1000                               0.00113                            0.00145
# 2006                               0.00264                            0.00136
# 11012                              0.00207                            0.00007
# 20000                              0.00032                            0.00083
# 35000                              0.00175                            0.00103
# 70000                              0.00001                            0.00230
# 120000                             0.00078                            0.00103
#
#         fe_cndl_shift_M240_CLOSE_to_LOW_-1  \
# 1                                  0.00003
# 5                                  0.00003
# 1000                               0.00037
# 2006                               0.00103
# 11012                              0.00083
# 20000                              0.00011
# 35000                              0.00190
# 70000                              0.00027
# 120000                             0.00134
#
#         fe_cndl_shift_M1440_CLOSE_to_OPEN_-1  \
# 1                                    0.00002
# 5                                    0.00002
# 1000                                -0.00804
# 2006                                 0.00029
# 11012                               -0.00082
# 20000                               -0.00167
# 35000                               -0.00028
# 70000                                0.00294
# 120000                              -0.00216
#
#         fe_cndl_shift_M1440_HIGH_to_LOW_-1  \
# 1                                  0.00004
# 5                                  0.00004
# 1000                               0.01166
# 2006                               0.00473
# 11012                              0.00506
# 20000                              0.00478
# 35000                              0.00540
# 70000                              0.00623
# 120000                             0.00593
#
#         fe_cndl_shift_M1440_HIGH_to_CLOSE_-1  \
# 1                                    0.00001
# 5                                    0.00001
# 1000                                 0.01112
# 2006                                 0.00270
# 11012                                0.00326
# 20000                                0.00211
# 35000                                0.00288
# 70000                                0.00242
# 120000                               0.00331
#
#         fe_cndl_shift_M1440_HIGH_to_OPEN_-1  \
# 1                                   0.00003
# 5                                   0.00003
# 1000                                0.00308
# 2006                                0.00299
# 11012                               0.00244
# 20000                               0.00044
# 35000                               0.00260
# 70000                               0.00536
# 120000                              0.00115
#
#         fe_cndl_shift_M1440_OPEN_to_LOW_-1  \
# 1                                  0.00001
# 5                                  0.00001
# 1000                               0.00858
# 2006                               0.00174
# 11012                              0.00262
# 20000                              0.00434
# 35000                              0.00280
# 70000                              0.00087
# 120000                             0.00478
#
#         fe_cndl_shift_M1440_CLOSE_to_LOW_-1  symbol
# 1                                   0.00003  EURUSD
# 5                                   0.00003  EURUSD
# 1000                                0.00054  EURUSD
# 2006                                0.00203  EURUSD
# 11012                               0.00180  EURUSD
# 20000                               0.00267  EURUSD
# 35000                               0.00252  EURUSD
# 70000                               0.00381  EURUSD
# 120000                              0.00262  EURUSD

# %% [markdown]
# **Market Close**

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe
# 1                         3                    0                  0
# 5                         3                    0                  0
# 1000                      6                    0                  0
# 2006                     11                    0                  0
# 11012                    55                    0                  0
# 20000                   100                    0                  0
# 35000                   172                    0                  0
# 70000                   342                    0                  0
# 120000                  220                    0                  0
#
#         fe_time_quarter_start  fe_time_quarter_end  fe_time_year_start  \
# 1                           0                    0                   0
# 5                           0                    0                   0
# 1000                        0                    0                   0
# 2006                        0                    0                   0
# 11012                       0                    0                   0
# 20000                       0                    0                   0
# 35000                       0                    0                   0
# 70000                       0                    0                   0
# 120000                      0                    0                   0
#
#         fe_time_year_end  fe_time_hour  fe_time_minute  fe_time_isin_New_York  \
# 1                      0             0               5                      0
# 5                      0             0              25                      0
# 1000                   0            11              20                      0
# 2006                   0            23              10                      0
# 11012                  0             5              40                      0
# 20000                  0            10              40                      0
# 35000                  0            12              40                      0
# 70000                  0             1              20                      0
# 120000                 0            16               0                      1
#
#         fe_time_isin_Tokyo  fe_time_isin_Sydney  fe_time_isin_London  symbol
# 1                        0                    1                    0  EURUSD
# 5                        0                    1                    0  EURUSD
# 1000                     0                    0                    1  EURUSD
# 2006                     0                    1                    0  EURUSD
# 11012                    1                    1                    0  EURUSD
# 20000                    0                    0                    1  EURUSD
# 35000                    0                    0                    1  EURUSD
# 70000                    1                    1                    0  EURUSD
# 120000                   0                    0                    1  EURUSD

# %% [markdown]
# ### D) Window Features

# %%
history_fe_WIN_features(config_general)
# Out:
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> start history_fe_WIN_features fumc:
# INFO:test run:--> start history_fe_WIN_features fumc:
#   [test run][INFO]:---> symbol: EURUSD
# INFO:test run:---> symbol: EURUSD
#   [test run][INFO]:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
# INFO:test run:= = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = = =
#   [test run][INFO]:--> history_fe_WIN_features run successfully.
# INFO:test run:--> history_fe_WIN_features run successfully.

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/features/fe_WIN/fe_WIN_EURUSD.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000, 35000, 70000, 120000]]
# Out:
#                      _time  symbol  fe_WIN_min_W5_M5  fe_WIN_argmin_W5_M5  \
# 1      2023-01-03 00:05:00  EURUSD               NaN                  NaN
# 5      2023-01-03 00:25:00  EURUSD               0.2                 1.00
# 1000   2023-01-06 11:20:00  EURUSD               0.0                 0.00
# 2006   2023-01-11 23:10:00  EURUSD               1.3                 0.75
# 11012  2023-02-24 05:40:00  EURUSD               0.0                 0.00
# 20000  2023-04-10 10:40:00  EURUSD               2.2                 0.50
# 35000  2023-06-21 12:40:00  EURUSD               0.0                 0.00
# 70000  2023-12-08 01:20:00  EURUSD               0.0                 0.00
# 120000 2024-08-07 16:00:00  EURUSD               3.8                 1.00
#
#         fe_WIN_max_W5_M5  fe_WIN_argmax_W5_M5  fe_WIN_min_W10_M5  \
# 1                    NaN                  NaN                NaN
# 5                    0.1                 0.50                NaN
# 1000                11.7                 0.75                0.0
# 2006                 3.5                 1.00                1.3
# 11012                2.8                 1.00                4.6
# 20000                0.1                 1.00                4.0
# 35000                3.5                 0.75                5.9
# 70000                4.9                 1.00                0.0
# 120000               1.8                 0.25                5.6
#
#         fe_WIN_argmin_W10_M5  fe_WIN_max_W10_M5  fe_WIN_argmax_W10_M5  \
# 1                        NaN                NaN                   NaN
# 5                        NaN                NaN                   NaN
# 1000                  0.0000               17.6                0.8889
# 2006                  0.3333                3.5                0.4444
# 11012                 1.0000                2.8                0.4444
# 20000                 1.0000                0.6                0.5556
# 35000                 0.6667                3.5                0.3333
# 70000                 0.0000                4.9                0.4444
# 120000                0.7778                1.8                0.1111
#
#         fe_WIN_min_W48_M5  fe_WIN_argmin_W48_M5  fe_WIN_max_W48_M5  \
# 1                     NaN                   NaN                NaN
# 5                     NaN                   NaN                NaN
# 1000                  0.0                0.0000               21.2
# 2006                 14.6                0.9574                8.0
# 11012                 5.8                0.5319               11.5
# 20000                16.1                0.6596                0.6
# 35000                15.5                0.7447                5.2
# 70000                 0.1                0.5106               13.2
# 120000               10.1                0.7447                5.0
#
#         fe_WIN_argmax_W48_M5  fe_WIN_min_W288_M5  fe_WIN_argmin_W288_M5  \
# 1                        NaN                 NaN                    NaN
# 5                        NaN                 NaN                    NaN
# 1000                  0.2766                 0.0                 0.0000
# 2006                  0.3191                28.8                 0.5087
# 11012                 0.6809                23.5                 0.4390
# 20000                 0.1064                22.3                 0.8014
# 35000                 0.3404                29.3                 0.7909
# 70000                 0.9574                33.0                 0.7561
# 120000                0.3404                12.6                 0.3101
#
#         fe_WIN_max_W288_M5  fe_WIN_argmax_W288_M5  fe_WIN_min_W480_M5  \
# 1                      NaN                    NaN                 NaN
# 5                      NaN                    NaN                 NaN
# 1000                 120.7                 0.9930                 0.0
# 2006                  17.4                 0.2369                39.4
# 11012                 25.9                 0.8850                23.5
# 20000                 12.8                 0.8676                22.3
# 35000                 10.1                 0.8990                29.3
# 70000                 23.4                 0.2334                33.0
# 120000                13.6                 0.9233                15.9
#
#         fe_WIN_argmin_W480_M5  fe_WIN_max_W480_M5  fe_WIN_argmax_W480_M5
# 1                         NaN                 NaN                    NaN
# 5                         NaN                 NaN                    NaN
# 1000                   0.0000               122.9                 0.8121
# 2006                   0.7912                17.4                 0.1420
# 11012                  0.2630                54.1                 0.9248
# 20000                  0.4802                27.9                 0.9812
# 35000                  0.4739                19.6                 0.6451
# 70000                  0.4530                23.4                 0.1399
# 120000                 0.6451                42.6                 0.9040

# %% [markdown]
# ## Integrating All Features

# %%
history_columns_merge(config_general,general_mode=True)
# Out:
#   [test run][INFO]:- - - - - - - - - - - - - - - - - - - - - - - - -
# INFO:test run:- - - - - - - - - - - - - - - - - - - - - - - - -
#   [test run][INFO]:--> start history_columns_merge fumc:
# INFO:test run:--> start history_columns_merge fumc:
#   [test run][INFO]:--> add fe_time.
# INFO:test run:--> add fe_time.
#   [test run][INFO]: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
# INFO:test run: ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^  ^ - ^
#   [test run][INFO]:--> EURUSD | fe_cndl_shape_n_cntxt
# INFO:test run:--> EURUSD | fe_cndl_shape_n_cntxt
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shape_n_cntxt<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_cndl_shape_n_cntxt<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_cndl_shift
# INFO:test run:--> EURUSD | fe_cndl_shift
#   [test run][INFO]:--> EURUSD | -->fe_cndl_shift<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_cndl_shift<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_SMA
# INFO:test run:--> EURUSD | fe_SMA
#   [test run][INFO]:--> EURUSD | -->fe_SMA<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_SMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_RSI
# INFO:test run:--> EURUSD | fe_RSI
#   [test run][INFO]:--> EURUSD | -->fe_RSI<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_RSI<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_market_close
# INFO:test run:--> EURUSD | fe_market_close
#   [test run][INFO]:--> EURUSD | -->fe_market_close<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_market_close<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_EMA
# INFO:test run:--> EURUSD | fe_EMA
#   [test run][INFO]:--> EURUSD | -->fe_EMA<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_EMA<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_cndl
# INFO:test run:--> EURUSD | fe_cndl
#   [test run][INFO]:--> EURUSD | -->fe_cndl<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_cndl<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_ATR
# INFO:test run:--> EURUSD | fe_ATR
#   [test run][INFO]:--> EURUSD | -->fe_ATR<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_ATR<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_WIN
# INFO:test run:--> EURUSD | fe_WIN
#   [test run][INFO]:--> EURUSD | -->fe_WIN<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_WIN<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_ratio
# INFO:test run:--> EURUSD | fe_ratio
#   [test run][INFO]:--> EURUSD | -->fe_ratio<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_ratio<---- --------------------------
#   [test run][INFO]:--> EURUSD | fe_RSTD
# INFO:test run:--> EURUSD | fe_RSTD
#   [test run][INFO]:--> EURUSD | -->fe_RSTD<---- --------------------------
# INFO:test run:--> EURUSD | -->fe_RSTD<---- --------------------------
#   [test run][INFO]:--> (145152, 384)
# INFO:test run:--> (145152, 384)
#   [test run][INFO]:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	123971
# ] / 145152
# INFO:test run:--> number of nulls all in df_dataset: shape: (1,)
# Series: 'sum' [u32]
# [
# 	123971
# ] / 145152
#   [test run][INFO]:--> trg_cols:0 | fe_cols:383
# INFO:test run:--> trg_cols:0 | fe_cols:383
# Mem. usage decreased to 194.55 Mb (51.1% reduction)
#   [test run][INFO]:--> df final shape: (143665, 385) | dataset saved.
# INFO:test run:--> df final shape: (143665, 385) | dataset saved.
#   [test run][INFO]:--> history_fe_time run successfully.
# INFO:test run:--> history_fe_time run successfully.

# %%
import pandas as pd

df = pd.read_parquet(
    f"/content/ML-Algotrading-Project/dataset/data/dataset/dataset.parquet"
)
df.iloc[[1, 5, 1000, 2006, 11012, 20000, 35000, 70000, 120000]]
# Out:
#                      _time  fe
M60_CLOSE_W7_W14_cndl_M60  \
# 1                                             0.92447
# 5                                             0.92447
# 1000                                          0.66147
# 2006                                          0.85202
# 11012                                         1.24219
# 20000                                         1.09720
# 35000                                         0.76228
# 70000                                         0.96707
# 120000                                        0.85179
#
#         fe_ratio_RSI_EURUSD_M60_CLOSE_W7_W30_cndl_M60  \
# 1                                             0.93830
# 5                                             0.93830
# 1000                                          0.56106
# 2006                                          0.78994
# 11012                                         1.32987
# 20000                                         1.02517
# 35000                                         0.64236
# 70000                                         0.97903
# 120000                                        0.81822
#
#         fe_ratio_RSI_EURUSD_M240_CLOSE_W7_W14_cndl_M240  \
# 1                                               1.09920
# 5                                               1.09920
# 1000                                            1.01861
# 2006                                            0.90326
# 11012                                           0.97893
# 20000                                           0.77015
# 35000                                           0.86964
# 70000                                           1.05658
# 120000                                          1.12001
#
#         fe_ratio_RSI_EURUSD_M240_CLOSE_W7_W30_cndl_M240  \
# 1                                               1.21066
# 5                                               1.21066
# 1000                                            1.10077
# 2006                                            0.82459
# 11012                                           1.00778
# 20000                                           0.68171
# 35000                                           0.80534
# 70000                                           1.22125
# 120000                                          1.29479
#
#         fe_ratio_EMA_EURUSD_M5_CLOSE_W7_W60_cndl_M5  \
# 1                                           0.18333
# 5                                           0.21334
# 1000                                       -0.09465
# 2006                                       -9.42515
# 11012                                      -0.04950
# 20000                                       0.36801
# 35000                                      -1.04143
# 70000                                       0.00081
# 120000                                     -0.03096
#
#         fe_ratio_EMA_EURUSD_M5_CLOSE_W60_W336_cndl_M5  \
# 1                                             0.08811
# 5                                             0.15171
# 1000                                          1.26029
# 2006                                          0.02088
# 11012                                         1.20735
# 20000                                         0.25329
# 35000                                         0.48227
# 70000                                         0.10000
# 120000                                       -0.26993
#
#         fe_ratio_EMA_EURUSD_M5_CLOSE_W60_W1440_cndl_M5  \
# 1                                              0.03184
# 5                                              0.05710
# 1000                                          -0.22112
# 2006                                           0.05142
# 11012                                          3.04681
# 20000                                          1.39218
# 35000                                         -0.56372
# 70000                                          0.03553
# 120000                                        -0.08121
#
#         fe_ratio_SMA_EURUSD_M5_CLOSE_W240_W720_cndl_M5  \
# 1                                              0.16447
# 5                                              0.18357
# 1000                                          -1.22493
# 2006                                           1.12334
# 11012                                         -2.85007
# 20000                                          0.22549
# 35000                                         -2.27230
# 70000                                          0.25176
# 120000                                         0.19195
#
#         fe_ratio_SMA_EURUSD_M5_CLOSE_W360_W720_cndl_M5  \
# 1                                              0.32427
# 5                                              0.33907
# 1000                                          -0.36034
# 2006                                           0.62363
# 11012                                         -0.56173
# 20000                                          0.69338
# 35000                                         -2.23417
# 70000                                          0.43562
# 120000                                         0.43924
#
#         fe_ratio_ATR_EURUSD_M60_CLOSE_W7_W14_cndl_M60  \
# 1                                             0.69723
# 5                                             0.69723
# 1000                                          1.23934
# 2006                                          0.39847
# 11012                                         0.90909
# 20000                                         1.20046
# 35000                                         1.39653
# 70000                                         0.49125
# 120000                                        1.24266
#
#         fe_ratio_ATR_EURUSD_M60_CLOSE_W7_W30_cndl_M60  \
# 1                                             0.75827
# 5                                             0.75827
# 1000                                          0.94337
# 2006                                          0.44958
# 11012                                         0.69614
# 20000                                         1.00515
# 35000                                         1.43411
# 70000                                         0.57154
# 120000                                        1.35538
#
#         fe_ratio_ATR_EURUSD_M240_CLOSE_W7_W14_cndl_M240  \
# 1                                               0.88455
# 5                                               0.88455
# 1000                                            1.25670
# 2006                                            1.14394
# 11012                                           0.89636
# 20000                                           1.13031
# 35000                                           1.06455
# 70000                                           1.07966
# 120000                                          1.21082
#
#         fe_ratio_ATR_EURUSD_M240_CLOSE_W7_W30_cndl_M240  \
# 1                                               0.83030
# 5                                               0.83030
# 1000                                            1.24592
# 2006                                            1.12953
# 11012                                           0.92709
# 20000                                           1.18825
# 35000                                           0.96408
# 70000                                           1.21266
# 120000                                          1.39675
#
#         fe_ratio_RSTD_EURUSD_M240_CLOSE_W7_W14_cndl_M240  \
# 1                                                0.76931
# 5                                                0.76931
# 1000                                             1.36569
# 2006                                             1.25567
# 11012                                            0.85037
# 20000                                            1.02158
# 35000                                            1.03124
# 70000                                            0.88828
# 120000                                           1.12402
#
#         fe_ratio_RSTD_EURUSD_M240_CLOSE_W7_W30_cndl_M240  \
# 1                                                0.65668
# 5                                                0.65668
# 1000                                             1.03058
# 2006                                             1.44965
# 11012                                            0.87616
# 20000                                            1.03668
# 35000                                            0.66128
# 70000                                            1.13018
# 120000                                           1.15230
#
#         fe_RSTD_EURUSD_M240_CLOSE_W14_cndl_M240  \
# 1                                     28.851866
# 5                                     28.851866
# 1000                                  17.349237
# 2006                                  33.624756
# 11012                                 20.490879
# 20000                                 21.546791
# 35000                                 13.515774
# 70000                                 27.799011
# 120000                                11.737267
#
#         fe_RSTD_EURUSD_M240_CLOSE_W7_cndl_M240  \
# 1                                    22.196075
# 5                                    22.196075
# 1000                                 23.693676
# 2006                                 42.221737
# 11012                                17.424744
# 20000                                22.011786
# 35000                                13.938065
# 70000                                24.693329
# 120000                               13.192917
#
#         fe_RSTD_EURUSD_M240_CLOSE_W30_cndl_M240   symbol
# 1                                     33.800598  dataset
# 5                                     33.800598  dataset
# 1000                                  22.990681  dataset
# 2006                                  29.125542  dataset
# 11012                                 19.887671  dataset
# 20000                                 21.233007  dataset
# 35000                                 21.077250  dataset
# 70000                                 21.849094  dataset
# 120000                                11.449204  dataset

# %% [markdown]
# # 1. Single Experiment (Manual)

# %%
print('MANUAL_EXP:',MANUAL_EXP)
man_params = {'RF':None, 'XGB':None}
# Out:
# MANUAL_EXP: True

# %%
man_params['RF'] = {
    'model_name' : 'RF',

    'target_symbol' : 'EURUSD',
    'trade_mode': 'long' ,   #"long" , "short"
    'trg_look_ahead' : 300,
    'trg_take_profit' : 40,
    'trg_stop_loss' : 15,

    'strg_look_ahead' : 300,
    'strg_take_profit' : 40,
    'strg_stop_loss' : 15,
    'use_dynamic_sl': True,
    'dynamic_sl_scale_type': 'second_tercile',  # 'median', 'second_tercile', 'third_quartile'
    'rstd_window_size': 12,


    'n_rand_features': None,
    'save_model_mode' : None, # None, 'sample_train_size', 'last_train_size', 'all_data',
    'n_splits' : 18,
    'max_train_size' : 500*288,
    'test_size' : 30*288,
    'train_test_gap':30*288,

    'parameters':{
        'n_estimators' : 100,
        'max_depth': 5,
        'max_features' : 64,
        'max_samples' : 0.5,
        'class_weight': {0:1,1:1}, # 'balanced'
        'random_state': 42,
        'n_jobs': -1
        }
              }

# %%
man_params['XGB'] = {
    'model_name' : 'XGB',

    'target_symbol' : 'EURUSD',
    'trade_mode': 'long' ,   #"long" , "short"
    'trg_look_ahead' : 400,
    'trg_take_profit' : 30,
    'trg_stop_loss' : 7,

    'strg_look_ahead' : 300,
    'strg_take_profit' : 30,
    'strg_stop_loss' : 20,
    'use_dynamic_sl': True,
    'dynamic_sl_scale_type': 'second_tercile',  # 'median', 'second_tercile', 'third_quartile'
    'rstd_window_size': 12,

    'n_rand_features': None,
    'save_model_mode' : None, # None, 'sample_train_size', 'last_train_size', 'all_data',
    'n_splits' : 3,
    'max_train_size' : 900*288,
    'test_size' : 30*288,
    'train_test_gap':30*288,

    "parameters": {
        'tree_method':'hist',#  None,hist
        'device' : 'cpu',#  None,'cuda'
        "objective": "binary:logistic",
        "max_depth": 7,
        "learning_rate": 0.15,
        "n_estimators": 50,
    #         "early_stopping_rounds" :{"distribution": "int_uniform", "min": 5, "max": 150},
        "early_stopping_rounds" :None,

#         "gamma": 7, #? float
#         "min_child_weight": 1,
        # Used to control over-fitting.
#         "max_delta_step": 2, #?float
        "subsample": 0.5,
        "colsample_bytree": 0.8,
        "reg_lambda": 0.01,
        "reg_alpha": 0.01,
        "scale_pos_weight" :1,
        'random_state': 0,
        },
}

# %%
if MANUAL_EXP:
  # Run with dynamic SL/TP
  man_params['XGB']['use_dynamic_sl'] = True
  exp_obj_dynamic, exp_metadata_dynamic, artifact_name_dynamic = main(
        manual=True,
        man_params=man_params['XGB'],
        dataset_path="/content/ML-Algotrading-Project/dataset/data/dataset/dataset.parquet",
        C5M_data_path="/content/ML-Algotrading-Project/dataset/data/stage_one_data/",
  )
# Out:
# Final Parameters of the Model: {'tree_method': 'hist', 'device': 'cpu', 'objective': 'binary:logistic', 'max_depth': 7, 'learning_rate': 0.15, 'n_estimators': 50, 'early_stopping_rounds': None, 'subsample': 0.5, 'colsample_bytree': 0.8, 'reg_lambda': 0.01, 'reg_alpha': 0.01, 'scale_pos_weight': 1, 'random_state': 0}
# Len all columns in dataframe is 385
# Len read columns is 385
# Calculating target --->
# ---> Target trg_clf_long_EURUSD_M400_TP30_SL7 has been generated in 2.16 seconds
# df shape:  (143585, 386)
# ==============================
# --> df final shape: (143585, 385)
# --> df min_time: 2023-01-10 03:55:00 | df max_time: 2024-12-06 17:15:00
# --> number of unique days: 143585
# ==============================
# Percentage of the True Class: 7.3
# Fold 0:
# --> fold train size: (83105, 390)
# --> fold valid size: (8640, 390)
# --> fold test size: (8640, 390)
#   dataset  K  f1_score  precision  recall    TP   FP     TN    FN  \
# 0   train  0      0.87       0.97    0.79  5228  147  76367  1363
# 1   valid  0      0.01       0.04    0.01     4  105   8023   508
# 2    test  0      0.02       0.05    0.01     6  106   8066   462
#
#              Min_date            Max_date train_duration  profit_percent  \
# 0 2023-01-10 03:55:00 2024-02-16 17:15:00           20.9             NaN
# 1 2024-03-29 17:20:00 2024-05-10 17:15:00           20.9           89.65
# 2 2024-05-10 17:20:00 2024-06-21 17:15:00           20.9          -31.35
#
#    max_dd n_unique_days n_max_daily_sig
# 0     NaN          None            None
# 1  -14.09            12              30
# 2  -56.42            14              35
# Fold 1:
# --> fold train size: (100385, 390)
# --> fold valid size: (8640, 390)
# --> fold test size: (8640, 390)
#   dataset  K  f1_score  precision  recall    TP   FP     TN    FN  \
# 3   train  1      0.83       0.97    0.73  5478  172  92698  2037
# 4   valid  1      0.01       0.10    0.01     3   28   8130   479
# 5    test  1      0.00       0.00    0.00     0   33   8060   547
#
#              Min_date            Max_date train_duration  profit_percent  \
# 3 2023-01-10 03:55:00 2024-05-10 17:15:00           20.9             NaN
# 4 2024-06-21 17:20:00 2024-08-02 17:15:00           20.9            9.80
# 5 2024-08-02 17:20:00 2024-09-13 17:15:00           20.9          -35.24
#
#    max_dd n_unique_days n_max_daily_sig
# 3     NaN          None            None
# 4   -6.64             4              11
# 5  -41.27             9              20
# Fold 2:
# --> fold train size: (117665, 390)
# --> fold valid size: (8640, 390)
# --> fold test size: (8640, 390)
#   dataset  K  f1_score  precision  recall    TP   FP      TN    FN  \
# 6   train  2      0.83       0.97    0.72  6091  168  109032  2374
# 7   valid  2      0.00       0.00    0.00     0    4    8226   410
# 8    test  2      0.02       0.15    0.01    12   69    7485  1074
#
#              Min_date            Max_date train_duration  profit_percent  \
# 6 2023-01-10 03:55:00 2024-08-02 17:15:00           37.4             NaN
# 7 2024-09-13 17:20:00 2024-10-25 17:15:00           37.4           -8.80
# 8 2024-10-25 17:20:00 2024-12-06 17:15:00           37.4           -9.56
#
#    max_dd n_unique_days n_max_daily_sig
# 6     NaN          None            None
# 7   -6.75             2               3
# 8  -41.31            13              17
# CV loop ends
# {'profit_percent_val': 90.65, 'max_dd_val': -14.09, 'profit_percent_test': -76.16, 'max_dd_test': -108.18}
# object stored as pickle: XGB_long_EURUSD_M400_TP30_SL7_prof-76.16_max_dd-108.18_median_sig75.00_date2024-12-08_16:02.pkl
# object pickle stored zipped: XGB_long_EURUSD_M400_TP30_SL7_prof-76.16_max_dd-108.18_median_sig75.00_date2024-12-08_16:02.pkl

# %%
if MANUAL_EXP:
  # Run with fixed SL/TP
  man_params['XGB']['use_dynamic_sl'] = False
  exp_obj_fixed, exp_metadata_fixed, artifact_name_fixed = main(
      manual=True,
      man_params=man_params['XGB'],
      dataset_path="/content/ML-Algotrading-Project/dataset/data/dataset/dataset.parquet",
      C5M_data_path="/content/ML-Algotrading-Project/dataset/data/stage_one_data/",
  )
# Out:
# Final Parameters of the Model: {'tree_method': 'hist', 'device': 'cpu', 'objective': 'binary:logistic', 'max_depth': 7, 'learning_rate': 0.15, 'n_estimators': 50, 'early_stopping_rounds': None, 'subsample': 0.5, 'colsample_bytree': 0.8, 'reg_lambda': 0.01, 'reg_alpha': 0.01, 'scale_pos_weight': 1, 'random_state': 0}
# Len all columns in dataframe is 385
# Len read columns is 385
# Calculating target --->
# ---> Target trg_clf_long_EURUSD_M400_TP30_SL7 has been generated in 2.51 seconds
# df shape:  (143585, 386)
# ==============================
# --> df final shape: (143585, 385)
# --> df min_time: 2023-01-10 03:55:00 | df max_time: 2024-12-06 17:15:00
# --> number of unique days: 143585
# ==============================
# Percentage of the True Class: 7.3
# Fold 0:
# --> fold train size: (83105, 390)
# --> fold valid size: (8640, 390)
# --> fold test size: (8640, 390)
#   dataset  K  f1_score  precision  recall    TP   FP     TN    FN  \
# 0   train  0      0.87       0.97    0.79  5228  147  76367  1363
# 1   valid  0      0.01       0.04    0.01     4  105   8023   508
# 2    test  0      0.02       0.05    0.01     6  106   8066   462
#
#              Min_date            Max_date train_duration  profit_percent  \
# 0 2023-01-10 03:55:00 2024-02-16 17:15:00           28.2             NaN
# 1 2024-03-29 17:20:00 2024-05-10 17:15:00           28.2           75.72
# 2 2024-05-10 17:20:00 2024-06-21 17:15:00           28.2          -40.48
#
#    max_dd n_unique_days n_max_daily_sig
# 0     NaN          None            None
# 1  -15.33            12              30
# 2  -64.69            14              35
# Fold 1:
# --> fold train size: (100385, 390)
# --> fold valid size: (8640, 390)
# --> fold test size: (8640, 390)
#   dataset  K  f1_score  precision  recall    TP   FP     TN    FN  \
# 3   train  1      0.83       0.97    0.73  5478  172  92698  2037
# 4   valid  1      0.01       0.10    0.01     3   28   8130   479
# 5    test  1      0.00       0.00    0.00     0   33   8060   547
#
#              Min_date            Max_date train_duration  profit_percent  \
# 3 2023-01-10 03:55:00 2024-05-10 17:15:00           23.1             NaN
# 4 2024-06-21 17:20:00 2024-08-02 17:15:00           23.1           13.39
# 5 2024-08-02 17:20:00 2024-09-13 17:15:00           23.1          -39.26
#
#    max_dd n_unique_days n_max_daily_sig
# 3     NaN          None            None
# 4   -4.55             4              11
# 5  -44.91             9              20
# Fold 2:
# --> fold train size: (117665, 390)
# --> fold valid size: (8640, 390)
# --> fold test size: (8640, 390)
#   dataset  K  f1_score  precision  recall    TP   FP      TN    FN  \
# 6   train  2      0.83       0.97    0.72  6091  168  109032  2374
# 7   valid  2      0.00       0.00    0.00     0    4    8226   410
# 8    test  2      0.02       0.15    0.01    12   69    7485  1074
#
#              Min_date            Max_date train_duration  profit_percent  \
# 6 2023-01-10 03:55:00 2024-08-02 17:15:00           25.9             NaN
# 7 2024-09-13 17:20:00 2024-10-25 17:15:00           25.9           -8.80
# 8 2024-10-25 17:20:00 2024-12-06 17:15:00           25.9          -12.53
#
#    max_dd n_unique_days n_max_daily_sig
# 6     NaN          None            None
# 7   -6.75             2               3
# 8  -43.43            13              17
# CV loop ends
# {'profit_percent_val': 80.31, 'max_dd_val': -15.33, 'profit_percent_test': -92.27, 'max_dd_test': -120.96}
# object stored as pickle: XGB_long_EURUSD_M400_TP30_SL7_prof-92.27_max_dd-120.96_median_sig75.00_date2024-12-08_16:03.pkl
# object pickle stored zipped: XGB_long_EURUSD_M400_TP30_SL7_prof-92.27_max_dd-120.96_median_sig75.00_date2024-12-08_16:03.pkl

# %%
# exp_metadata_dynamic['selected_evals']

# %%
# Val
# Extract metrics for dynamic SL/TP
XGB_profit_dynamic_val = exp_metadata_dynamic['selected_evals']['profit_percent_val']
XGB_drawdown_dynamic_val = exp_metadata_dynamic['selected_evals']['max_dd_val']

# Extract metrics for fixed SL/TP
XGB_profit_fixed_val = exp_metadata_fixed['selected_evals']['profit_percent_val']
XGB_drawdown_fixed_val = exp_metadata_fixed['selected_evals']['max_dd_val']

# Print results
print("Dynamic SL/TP:")
print(f"Profit: {XGB_profit_dynamic_val:.2f}%")
print(f"Max Drawdown: {XGB_drawdown_dynamic_val:.2f}%")

print("\nFixed SL/TP:")
print(f"Profit: {XGB_profit_fixed_val:.2f}%")
print(f"Max Drawdown: {XGB_drawdown_fixed_val:.2f}%")
# Out:
# Dynamic SL/TP:
# Profit: 90.65%
# Max Drawdown: -14.09%
#
# Fixed SL/TP:
# Profit: 80.31%
# Max Drawdown: -15.33%

# %%
# Test
# Extract metrics for dynamic SL/TP
XGB_profit_dynamic_test = exp_metadata_dynamic['selected_evals']['profit_percent_test']
XGB_drawdown_dynamic_test = exp_metadata_dynamic['selected_evals']['max_dd_test']

# Extract metrics for fixed SL/TP
XGB_profit_fixed_test = exp_metadata_fixed['selected_evals']['profit_percent_test']
XGB_drawdown_fixed_test = exp_metadata_fixed['selected_evals']['max_dd_test']

# Print results
print("Dynamic SL/TP:")
print(f"Profit: {XGB_profit_dynamic_test:.2f}%")
print(f"Max Drawdown: {XGB_drawdown_dynamic_test:.2f}%")

print("\nFixed SL/TP:")
print(f"Profit: {XGB_profit_fixed_test:.2f}%")
print(f"Max Drawdown: {XGB_drawdown_fixed_test:.2f}%")
# Out:
# Dynamic SL/TP:
# Profit: -76.16%
# Max Drawdown: -108.18%
#
# Fixed SL/TP:
# Profit: -92.27%
# Max Drawdown: -120.96%

# %%
# XGB_Val
import matplotlib.pyplot as plt

labels = ['Profit (%)', 'Max Drawdown (%)']
dynamic_values = [XGB_profit_dynamic_val, XGB_drawdown_dynamic_val]
fixed_values = [XGB_profit_fixed_val, XGB_drawdown_fixed_val]

x = range(len(labels))

plt.bar(x, dynamic_values, width=0.4, label='Dynamic SL/TP', align='center')
plt.bar([p + 0.4 for p in x], fixed_values, width=0.4, label='Fixed SL/TP', align='center')

plt.xlabel('Metrics')
plt.ylabel('Values')
plt.title('Comparison of Dynamic vs Fixed SL/TP in Validation - XGB')
plt.xticks([p + 0.2 for p in x], labels)
plt.legend()
plt.show()

# %%
# XGB_Test
import matplotlib.pyplot as plt

labels = ['Profit (%)', 'Max Drawdown (%)']
dynamic_values = [XGB_profit_dynamic_test, XGB_drawdown_dynamic_test]
fixed_values = [XGB_profit_fixed_test, XGB_drawdown_fixed_test]

x = range(len(labels))

plt.bar(x, dynamic_values, width=0.4, label='Dynamic SL/TP', align='center')
plt.bar([p + 0.4 for p in x], fixed_values, width=0.4, label='Fixed SL/TP', align='center')

plt.xlabel('Metrics')
plt.ylabel('Values')
plt.title('Comparison of Dynamic vs Fixed SL/TP in Test - XGB')
plt.xticks([p + 0.2 for p in x], labels)
plt.legend()
plt.show()

# %%
imp_fe = list(exp_obj.feature_importance[exp_obj.feature_importance.cv<.5].feature_name)
exp_obj.feature_importance[exp_obj.feature_importance.cv<.5].feature_name
# Out:
# 18                                   fe_time_isin_London
# 296                   fe_market_close_EURUSD_London_time
# 294                   fe_market_close_EURUSD_Sydney_time
# 379     fe_ratio_RSTD_EURUSD_M240_CLOSE_W7_W30_cndl_M240
# 107    fe_cndl_EURUSD_shape_n_cntxt_up_shadow_M60_nor...
#                              ...
# 75     fe_cndl_EURUSD_shape_n_cntxt_body_length_M5_no...
# 46     fe_cndl_EURUSD_shape_n_cntxt_up_shadow_M5_norm...
# 31     fe_cndl_EURUSD_shape_n_cntxt_return_M5_norm_lag_4
# 21      fe_cndl_EURUSD_shape_n_cntxt_down_shadow_M5_norm
# 72     fe_cndl_EURUSD_shape_n_cntxt_body_length_M5_no...
# Name: feature_name, Length: 285, dtype: object

# %%
def plot_feature_importances_scatter(importance_df, top_n=10, figsize=(8, 6)):
    # Calculate mean importance and sort features
    mean_importance = importance_df['mean_importance']
    sorted_idx = mean_importance.argsort()[::-1]
    top_features = importance_df.iloc[sorted_idx[:top_n]]
    imp_cols = [f for f in importance_df if 'importance_fold' in f]
    # Prepare data for scatter plot
    feature_names = top_features['feature_name']
    importance_values = top_features[imp_cols].values.T  # Transpose for plotting

    # Calculate median importance
    median_importance = top_features['median_importance']

    # Create scatter plot
    fig, ax = plt.subplots(figsize=figsize)

    for i, feature in enumerate(feature_names):
        ax.scatter([i] * importance_values.shape[0], importance_values[:, i],
                   alpha=0.6, label=feature)

    # Plot median line
    ax.plot(range(top_n), median_importance, color='red', linestyle='--',
            linewidth=2, label='Median')

    # Add value labels on the median line
    for i, v in enumerate(median_importance):
        ax.text(i, v, f'{v:.3f}', ha='center', va='bottom', fontweight='bold')

    ax.set_xlabel('Features', fontsize=12)
    ax.set_ylabel('Feature Importance', fontsize=12)
    ax.set_title(f'Top {top_n} Feature Importances Across Folds with Median', fontsize=14)
    ax.set_xticks(range(top_n))
    ax.set_xticklabels(feature_names, rotation=45, ha='right')
#     ax.legend(title='Features', bbox_to_anchor=(1.05, 1), loc='upper left')

    plt.tight_layout()
    plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plot_feature_importances_scatter(exp_obj.feature_importance)

# %%
# Dynamically adjust n_splits based on available data
max_splits = (143605 // (man_params['RF']['test_size'] + man_params['RF']['train_test_gap']))
man_params['RF']['n_splits'] = min(man_params['RF']['n_splits'], max_splits)
print(max_splits)
print(man_params['RF']['n_splits'])
# Out:
# 7
# 5

# %%
if MANUAL_EXP:
  # Dynamically compute valid n_splits
  max_splits = 7  # Adjust total_samples / (test_size + gap)
  man_params['RF']['n_splits'] = 3

  # Adjust test size and gap if necessary
  man_params['RF']['test_size'] = 15000
  man_params['RF']['train_test_gap'] = 3000

  # Run with dynamic SL/TP
  man_params['RF']['use_dynamic_sl'] = True
  exp_obj_dynamic, exp_metadata_dynamic, artifact_name_dynamic = main(
      manual=True,
      man_params=man_params['RF'],
      dataset_path="/content/ML-Algotrading-Project/dataset/data/dataset/dataset.parquet",
      C5M_data_path="/content/ML-Algotrading-Project/dataset/data/stage_one_data/",
  )
# Out:
# Final Parameters of the Model: {'n_estimators': 100, 'max_depth': 5, 'max_features': 64, 'max_samples': 0.5, 'class_weight': {0: 1, 1: 1}, 'random_state': 42, 'n_jobs': -1}
# Len all columns in dataframe is 385
# Len read columns is 385
# Calculating target --->
# ---> Target trg_clf_long_EURUSD_M300_TP40_SL15 has been generated in 3.93 seconds
# df shape:  (143605, 386)
# ==============================
# --> df final shape: (143605, 385)
# --> df min_time: 2023-01-10 03:55:00 | df max_time: 2024-12-06 18:55:00
# --> number of unique days: 143605
# ==============================
# Percentage of the True Class: 4.2
# Fold 0:
# --> fold train size: (50605, 390)
# --> fold valid size: (15000, 390)
# --> fold test size: (15000, 390)
#   dataset  K  f1_score  precision  recall   TP  FP     TN    FN  \
# 0   train  0      0.07        1.0    0.04  106   0  47790  2709
# 1   valid  0      0.00        0.0    0.00    0   0  14330   670
# 2    test  0      0.00        0.0    0.00    0   0  14499   501
#
#              Min_date            Max_date train_duration profit_percent  \
# 0 2023-01-10 03:55:00 2023-09-12 20:55:00           52.7           None
# 1 2023-09-27 07:00:00 2023-12-08 08:55:00           52.7              0
# 2 2023-12-08 09:00:00 2024-02-20 10:55:00           52.7              0
#
#   max_dd n_unique_days n_max_daily_sig
# 0   None          None            None
# 1      0             0            None
# 2      0             0             NaN
# Fold 1:
# --> fold train size: (80605, 390)
# --> fold valid size: (15000, 390)
# --> fold test size: (15000, 390)
#   dataset  K  f1_score  precision  recall   TP  FP     TN    FN  \
# 3   train  1      0.05       0.99    0.03  109   1  76656  3839
# 4   valid  1      0.00       0.00    0.00    0   0  14620   380
# 5    test  1      0.13       1.00    0.07   28   0  14581   391
#
#              Min_date            Max_date train_duration profit_percent  \
# 3 2023-01-10 03:55:00 2024-02-06 00:55:00           94.9           None
# 4 2024-02-20 11:00:00 2024-05-02 12:55:00           94.9              0
# 5 2024-05-02 13:00:00 2024-07-15 14:55:00           94.9          75.28
#
#   max_dd n_unique_days n_max_daily_sig
# 3   None          None            None
# 4      0             0             NaN
# 5    0.0             1              28
# Fold 2:
# --> fold train size: (110605, 390)
# --> fold valid size: (15000, 390)
# --> fold test size: (15000, 390)
#   dataset  K  f1_score  precision  recall  TP  FP      TN    FN  \
# 6   train  2      0.03        1.0    0.02  81   0  105913  4611
# 7   valid  2      0.00        0.0    0.00   0   0   14570   430
# 8    test  2      0.00        0.0    0.00   0   0   14250   750
#
#              Min_date            Max_date train_duration profit_percent  \
# 6 2023-01-10 03:55:00 2024-07-01 04:55:00          132.6           None
# 7 2024-07-15 15:00:00 2024-09-25 16:55:00          132.6              0
# 8 2024-09-25 17:00:00 2024-12-06 18:55:00          132.6              0
#
#   max_dd n_unique_days n_max_daily_sig
# 6   None          None            None
# 7      0             0             NaN
# 8      0             0             NaN
# CV loop ends
# {'profit_percent_val': 0, 'max_dd_val': 0, 'profit_percent_test': 75.28, 'max_dd_test': 0.0}
# /content/ML-Algotrading-Project/utils/evaluation_utils.py:40: RuntimeWarning: invalid value encountered in scalar divide
#   f"precision_total_{set_name}": evals_df.TP.sum() / (evals_df.TP.sum() + evals_df.FP.sum()),
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# object stored as pickle: RF_long_EURUSD_M300_TP40_SL15_prof75.28_max_dd0.00_median_sig0.00_date2024-12-08_16:55.pkl
# object pickle stored zipped: RF_long_EURUSD_M300_TP40_SL15_prof75.28_max_dd0.00_median_sig0.00_date2024-12-08_16:55.pkl

# %%
if MANUAL_EXP:
  # Run with fixed SL/TP
  man_params['RF']['use_dynamic_sl'] = False

  exp_obj_fixed, exp_metadata_fixed, artifact_name_fixed = main(
      manual=True,
      man_params=man_params['RF'],
      dataset_path="/content/ML-Algotrading-Project/dataset/data/dataset/dataset.parquet",
      C5M_data_path="/content/ML-Algotrading-Project/dataset/data/stage_one_data/",
  )
# Out:
# Final Parameters of the Model: {'n_estimators': 100, 'max_depth': 5, 'max_features': 64, 'max_samples': 0.5, 'class_weight': {0: 1, 1: 1}, 'random_state': 42, 'n_jobs': -1}
# Len all columns in dataframe is 385
# Len read columns is 385
# Calculating target --->
# ---> Target trg_clf_long_EURUSD_M300_TP40_SL15 has been generated in 2.86 seconds
# df shape:  (143605, 386)
# ==============================
# --> df final shape: (143605, 385)
# --> df min_time: 2023-01-10 03:55:00 | df max_time: 2024-12-06 18:55:00
# --> number of unique days: 143605
# ==============================
# Percentage of the True Class: 4.2
# Fold 0:
# --> fold train size: (50605, 390)
# --> fold valid size: (15000, 390)
# --> fold test size: (15000, 390)
#   dataset  K  f1_score  precision  recall   TP  FP     TN    FN  \
# 0   train  0      0.07        1.0    0.04  106   0  47790  2709
# 1   valid  0      0.00        0.0    0.00    0   0  14330   670
# 2    test  0      0.00        0.0    0.00    0   0  14499   501
#
#              Min_date            Max_date train_duration profit_percent  \
# 0 2023-01-10 03:55:00 2023-09-12 20:55:00           54.8           None
# 1 2023-09-27 07:00:00 2023-12-08 08:55:00           54.8              0
# 2 2023-12-08 09:00:00 2024-02-20 10:55:00           54.8              0
#
#   max_dd n_unique_days n_max_daily_sig
# 0   None          None            None
# 1      0             0            None
# 2      0             0             NaN
# Fold 1:
# --> fold train size: (80605, 390)
# --> fold valid size: (15000, 390)
# --> fold test size: (15000, 390)
#   dataset  K  f1_score  precision  recall   TP  FP     TN    FN  \
# 3   train  1      0.05       0.99    0.03  109   1  76656  3839
# 4   valid  1      0.00       0.00    0.00    0   0  14620   380
# 5    test  1      0.13       1.00    0.07   28   0  14581   391
#
#              Min_date            Max_date train_duration profit_percent  \
# 3 2023-01-10 03:55:00 2024-02-06 00:55:00           91.5           None
# 4 2024-02-20 11:00:00 2024-05-02 12:55:00           91.5              0
# 5 2024-05-02 13:00:00 2024-07-15 14:55:00           91.5          106.4
#
#   max_dd n_unique_days n_max_daily_sig
# 3   None          None            None
# 4      0             0             NaN
# 5    0.0             1              28
# Fold 2:
# --> fold train size: (110605, 390)
# --> fold valid size: (15000, 390)
# --> fold test size: (15000, 390)
#   dataset  K  f1_score  precision  recall  TP  FP      TN    FN  \
# 6   train  2      0.03        1.0    0.02  81   0  105913  4611
# 7   valid  2      0.00        0.0    0.00   0   0   14570   430
# 8    test  2      0.00        0.0    0.00   0   0   14250   750
#
#              Min_date            Max_date train_duration profit_percent  \
# 6 2023-01-10 03:55:00 2024-07-01 04:55:00          128.2           None
# 7 2024-07-15 15:00:00 2024-09-25 16:55:00          128.2              0
# 8 2024-09-25 17:00:00 2024-12-06 18:55:00          128.2              0
#
#   max_dd n_unique_days n_max_daily_sig
# 6   None          None            None
# 7      0             0             NaN
# 8      0             0             NaN
# CV loop ends
# {'profit_percent_val': 0, 'max_dd_val': 0, 'profit_percent_test': 106.4, 'max_dd_test': 0.0}
# /content/ML-Algotrading-Project/utils/evaluation_utils.py:40: RuntimeWarning: invalid value encountered in scalar divide
#   f"precision_total_{set_name}": evals_df.TP.sum() / (evals_df.TP.sum() + evals_df.FP.sum()),
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /usr/local/lib/python3.10/dist-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# object stored as pickle: RF_long_EURUSD_M300_TP40_SL15_prof106.40_max_dd0.00_median_sig0.00_date2024-12-08_17:00.pkl
# object pickle stored zipped: RF_long_EURUSD_M300_TP40_SL15_prof106.40_max_dd0.00_median_sig0.00_date2024-12-08_17:00.pkl

# %%
# exp_metadata_dynamic['selected_evals']

# %%
# Val
# Extract metrics for dynamic SL/TP
RF_profit_dynamic_val = exp_metadata_dynamic['selected_evals']['profit_percent_val']
RF_drawdown_dynamic_val = exp_metadata_dynamic['selected_evals']['max_dd_val']

# Extract metrics for fixed SL/TP
RF_profit_fixed_val = exp_metadata_fixed['selected_evals']['profit_percent_val']
RF_drawdown_fixed_val = exp_metadata_fixed['selected_evals']['max_dd_val']

# Print results
print("Dynamic SL/TP:")
print(f"Profit: {RF_profit_dynamic_val:.2f}%")
print(f"Max Drawdown: {RF_drawdown_dynamic_val:.2f}%")

print("\nFixed SL/TP:")
print(f"Profit: {RF_profit_fixed_val:.2f}%")
print(f"Max Drawdown: {RF_drawdown_fixed_val:.2f}%")
# Out:
# Dynamic SL/TP:
# Profit: 0.00%
# Max Drawdown: 0.00%
#
# Fixed SL/TP:
# Profit: 0.00%
# Max Drawdown: 0.00%

# %%
# Test
# Extract metrics for dynamic SL/TP
RF_profit_dynamic_test = exp_metadata_dynamic['selected_evals']['profit_percent_test']
RF_drawdown_dynamic_test = exp_metadata_dynamic['selected_evals']['max_dd_test']

# Extract metrics for fixed SL/TP
RF_profit_fixed_test = exp_metadata_fixed['selected_evals']['profit_percent_test']
RF_drawdown_fixed_test = exp_metadata_fixed['selected_evals']['max_dd_test']

# Print results
print("Dynamic SL/TP:")
print(f"Profit: {RF_profit_dynamic_test:.2f}%")
print(f"Max Drawdown: {RF_drawdown_dynamic_test:.2f}%")

print("\nFixed SL/TP:")
print(f"Profit: {RF_profit_fixed_test:.2f}%")
print(f"Max Drawdown: {RF_drawdown_fixed_test:.2f}%")
# Out:
# Dynamic SL/TP:
# Profit: 75.28%
# Max Drawdown: 0.00%
#
# Fixed SL/TP:
# Profit: 106.40%
# Max Drawdown: 0.00%

# %%
# XGB_Val
import matplotlib.pyplot as plt

labels = ['Profit (%)', 'Max Drawdown (%)']
dynamic_values = [RF_profit_dynamic_val, RF_drawdown_dynamic_val]
fixed_values = [RF_profit_fixed_val, RF_drawdown_fixed_val]

x = range(len(labels))

plt.bar(x, dynamic_values, width=0.4, label='Dynamic SL/TP', align='center')
plt.bar([p + 0.4 for p in x], fixed_values, width=0.4, label='Fixed SL/TP', align='center')

plt.xlabel('Metrics')
plt.ylabel('Values')
plt.title('Comparison of Dynamic vs Fixed SL/TP in Validation - RF')
plt.xticks([p + 0.2 for p in x], labels)
plt.legend()
plt.show()

# %%
# XGB_Test
import matplotlib.pyplot as plt

labels = ['Profit (%)', 'Max Drawdown (%)']
dynamic_values = [RF_profit_dynamic_test, RF_drawdown_dynamic_test]
fixed_values = [RF_profit_fixed_test, RF_drawdown_fixed_test]

x = range(len(labels))

plt.bar(x, dynamic_values, width=0.4, label='Dynamic SL/TP', align='center')
plt.bar([p + 0.4 for p in x], fixed_values, width=0.4, label='Fixed SL/TP', align='center')

plt.xlabel('Metrics')
plt.ylabel('Values')
plt.title('Comparison of Dynamic vs Fixed SL/TP in Test - RF')
plt.xticks([p + 0.2 for p in x], labels)
plt.legend()
plt.show()

# %%
imp_fe = list(exp_obj.feature_importance[exp_obj.feature_importance.cv<.5].feature_name)
exp_obj.feature_importance[exp_obj.feature_importance.cv<.5].feature_name
# Out:
# 18                                   fe_time_isin_London
# 296                   fe_market_close_EURUSD_London_time
# 294                   fe_market_close_EURUSD_Sydney_time
# 379     fe_ratio_RSTD_EURUSD_M240_CLOSE_W7_W30_cndl_M240
# 107    fe_cndl_EURUSD_shape_n_cntxt_up_shadow_M60_nor...
#                              ...
# 75     fe_cndl_EURUSD_shape_n_cntxt_body_length_M5_no...
# 46     fe_cndl_EURUSD_shape_n_cntxt_up_shadow_M5_norm...
# 31     fe_cndl_EURUSD_shape_n_cntxt_return_M5_norm_lag_4
# 21      fe_cndl_EURUSD_shape_n_cntxt_down_shadow_M5_norm
# 72     fe_cndl_EURUSD_shape_n_cntxt_body_length_M5_no...
# Name: feature_name, Length: 285, dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plot_feature_importances_scatter(exp_obj.feature_importance)

# %% [markdown]
# ### Save manual object on W&B as Artifact

# %%
if MANUAL_EXP:
    wandb.init(entity = 'alpha-hunters', project = 'algotrading-project')
    obj_artifact = wandb.Artifact(artifact_name, 'manual_experiment', metadata = exp_metadata)
    obj_artifact.add_file(local_path=exp_obj.store_name+'.zip', name=exp_obj.store_name+'.zip')
    wandb.log_artifact(obj_artifact)
# Out:
# wandb: Currently logged in as: amirhosseinfarahani (alpha-hunters). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/content/wandb/run-20241208_170842-smhwcoak</code>
# Syncing run <strong><a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/smhwcoak' target="_blank">curious-sky-2175</a></strong> to <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a>
#  View run at <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/smhwcoak' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/smhwcoak</a>

# %%
if MANUAL_EXP:
    wandb.finish()
# Out:
#  View run <strong style="color:#cdcd00">curious-sky-2175</strong> at: <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/smhwcoak' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/smhwcoak</a><br/> View project at: <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a><br/>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241208_170842-smhwcoak/logs</code>

# %% [markdown]
# ## Save imp_features (when we have RANDOM features)

# %%
if MANUAL_EXP:
    upload_imp_features = True
    symbol = man_params[model_type]['target_symbol']
    trade_mode = man_params[model_type]['trade_mode']
    look_ahead = man_params[model_type]['trg_look_ahead']
    take_profit = man_params[model_type]['trg_take_profit']
    stop_loss = man_params[model_type]['trg_stop_loss']

# %%
if MANUAL_EXP and upload_imp_features :
    print('save_imp_features ')
    import pickle as pkl
    the_name = f"df_feature_imp_{trade_mode}_{symbol}_M{look_ahead}_TP{take_profit}_SL{stop_loss}.pkl"
    file = open(the_name, 'wb')
    pkl.dump(exp_obj.feature_importance,file)
    file.close()

    imp_artifact_name = artifact_name + '_imp_features'
    wandb.init(entity = 'alpha-hunters', project = 'algotrading-project', job_type="feature_selection")
    imp_artifact = wandb.Artifact(imp_artifact_name, 'feature_selection', metadata = exp_metadata)
    imp_artifact.add_file(local_path = the_name,name = the_name)
    print(f"--> dataset size MB: {imp_artifact.size / 1000000}")
    wandb.log_artifact(imp_artifact)
    wandb.finish()
# Out:
# save_imp_features
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/content/wandb/run-20241208_171237-n98vljvi</code>
# Syncing run <strong><a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/n98vljvi' target="_blank">electric-smoke-2176</a></strong> to <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a>
#  View run at <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/n98vljvi' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/n98vljvi</a>
# --> dataset size MB: 0.032907
#  View run <strong style="color:#cdcd00">electric-smoke-2176</strong> at: <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/n98vljvi' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/n98vljvi</a><br/> View project at: <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a><br/>Synced 5 W&B file(s), 0 media file(s), 2 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241208_171237-n98vljvi/logs</code>

# %% [markdown]
# # 2. Sweep Experiment using W&B

# %%
sweep_configs = {}
sweep_configs['RF'] = {
    "method": "grid",
#     "metric": {"name": "class 1 f0.03_score_train", "goal": "maximize"},
#     'description':description,
    "parameters": {
        'model_name' : {"values": ['RF']},

        'target_symbol' : {"values": ['EURUSD']},
        'trade_mode' : {"values": ['long']},
        "trg_look_ahead": {"values": [120]},
        "trg_take_profit": {"values": [12]},
        "trg_stop_loss": {"values": [5]},

        "strg_look_ahead": {"values": [120]},
        "strg_take_profit": {"values": [40]},
        "strg_stop_loss": {"values": [20]},
        "use_dynamic_sl": {"values": [True]},
        "dynamic_sl_scale_type": {"values": ["second_tercile"]},  # 'median', 'second_tercile', 'third_quartile'
        "rstd_window_size": {"values": [12, 48]},

        'save_model_mode' : {"values": ['last_train_size']}, # None, 'sample_train_size', 'last_train_size', 'all_data',
        'imp_features' : {"values": [None]},  #  can be set to imp_features or None
        'n_rand_features': {"values": [None]},
        "early_stopping_rounds" :{"values": [None]},
        "n_splits" : {"values": [17]},
        "max_train_size": {"values": [500*288]},
        'test_size' : {"values": [30*288]},
        'train_test_gap' : {"values": [0]},


        'n_estimators' : {"values": [200]},
        'max_depth': {"values": [5,12]},
        'max_features' : {"values": [30, 50,80]},
        'max_samples' : {"values": [0.2,0.3,0.4]},
        'class_weight':{'values':[0.13,0.15, 0.18, 0.23]},
        'n_jobs': {"values": [-1]},
        'random_state' : {"values": [42]},

#         "objective": {"values": ["binary:logistic"]},

#         "max_depth": {"values": [2, 5, 8, 15, 20, 30]},
#         "learning_rate": {"distribution": "uniform", "min": 0.005, "max": 0.01},
#         "n_estimators": {"distribution": "int_uniform", "min": 50, "max": 300},
#         "min_child_weight": {"distribution": "uniform", "min": 0, "max": 1}, # Used to control over-fitting.
#         "subsample": {"distribution": "uniform", "min": 0.3, "max": 0.5 } ,#Lower values make the algorithm more conservative and prevents overfitting but too small values might lead to under-fitting.


#         "early_stopping_rounds" :{"distribution": "int_uniform", "min": 5, "max": 150},
#         "early_stopping_rounds" :{"values": [40,200]},
#         "gamma": {"distribution": "uniform", "min": 0, "max": 15}, #? float
#         "max_delta_step": {"distribution": "uniform", "min": 0, "max": 15}, #?float
#         "colsample_bytree": {"distribution": "uniform", "min": 0.5, "max": 0.75},
#         "reg_lambda": {"distribution": "uniform", "min": 0, "max": 10},
#         "reg_alpha": {"distribution": "uniform", "min": 0, "max": 10},
#         "train_data_precent": {"distribution": "uniform", "min": 0, "max": 0.98},
#         "train_data_precent": {"distribution": "uniform", "min": 0.5, "max": 0.95},
    },
}

# %%
sweep_configs['XGB'] = {
    "method": "grid",

    "parameters": {
        'model_name' : {"values": ['XGB']},

        'target_symbol' : {"values": ['EURUSD']}, # ["EURUSD","USDCAD","USDJPY","EURJPY","GBPUSD","XAUUSD"]
        'trade_mode' : {"values": ['long']}, # "long", "short"
        "trg_look_ahead": {"values": [300]},
        "trg_take_profit": {"values": [35]},
        "trg_stop_loss": {"values": [5]},

        "strg_look_ahead": {"values": [480]},
        "strg_take_profit": {"values": [40]},
        "strg_stop_loss": {"values": [20]},
        "use_dynamic_sl": {"values": [True]},
        "dynamic_sl_scale_type": {"values": ["second_tercile"]},  # 'median', 'second_tercile', 'third_quartile'
        "rstd_window_size": {"values": [12, 48]},

        'n_rand_features': {"values": [None]}, # None or Number
        'save_model_mode' : {"values": [None]}, # None, 'sample_train_size', 'last_train_size', 'all_data',

        "early_stopping_rounds" :{"values": [None]}, #None or Number
        'n_splits' : {"values":[3]},
        'max_train_size' : {"values":[400*288,300*288]},
        'test_size' : {"values":[30*288]},
        'train_test_gap' : {"values": [0]},

        "objective": {"values": ["binary:logistic"]},
        "max_depth": {"values": [4,5]},
        "learning_rate": {"values": [0.1,0.01,0.05]},
        'tree_method': {"values": [None]}, #'hist', None
        'device' : {"values": ["cpu"]}, # 'cuda', None
#         "learning_rate": {"distribution": "log_uniform", "min": 1e-5, "max": 5e-1},
        "n_estimators": {"values": [100]},
#         "early_stopping_rounds" :{"distribution": "int_uniform", "min": 5, "max": 150},
#         "early_stopping_rounds" :{"values": [40,200]},
#         "gamma": {"distribution": "uniform", "min": 0, "max": 15}, #? float
        "min_child_weight": {"values": [1]}, # Used to control over-fitting.
#         "max_delta_step": {"distribution": "uniform", "min": 0, "max": 15}, #?float
        "subsample": {"values": [0.3,0.5,0.8]},#Lower values make the algorithm more conservative and prevents overfitting but too small values might lead to under-fitting.
        "colsample_bytree": {"values": [0.5,0.8]},
        "reg_lambda": {"values": [0,0.02,0.1]},
#         "reg_alpha": {"distribution": "uniform", "min": 0, "max": 10},
        "scale_pos_weight" : {"values": [1]},#[1,0.95,1.1]
        'random_state': {"values":[42]},
        },
}

# %%
# %%time

sweep_id = wandb.sweep(
    sweep_configs[model_type],
    entity = 'alpha-hunters',
    project = 'algotrading-project'
)

#!!!!!!!!!!!! SWEEP ID !!!!!!!!!!!!!!!!!
wandb.agent(sweep_id = sweep_id, function = main, entity = 'alpha-hunters',project = 'algotrading-project')
wandb.finish()
# Out:
# Create sweep with ID: hp6nl3b7
# Sweep URL: https://wandb.ai/alpha-hunters/algotrading-project/sweeps/hp6nl3b7
# wandb: Agent Starting Run: aa5h708n with config:
# wandb: 	colsample_bytree: 0.5
# wandb: 	device: cpu
# wandb: 	dynamic_sl_scale_type: second_tercile
# wandb: 	early_stopping_rounds: None
# wandb: 	learning_rate: 0.1
# wandb: 	max_depth: 4
# wandb: 	max_train_size: 115200
# wandb: 	min_child_weight: 1
# wandb: 	model_name: XGB
# wandb: 	n_estimators: 100
# wandb: 	n_rand_features: None
# wandb: 	n_splits: 3
# wandb: 	objective: binary:logistic
# wandb: 	random_state: 42
# wandb: 	reg_lambda: 0
# wandb: 	rstd_window_size: 12
# wandb: 	save_model_mode: None
# wandb: 	scale_pos_weight: 1
# wandb: 	strg_look_ahead: 480
# wandb: 	strg_stop_loss: 20
# wandb: 	strg_take_profit: 40
# wandb: 	subsample: 0.3
# wandb: 	target_symbol: EURUSD
# wandb: 	test_size: 8640
# wandb: 	trade_mode: long
# wandb: 	train_test_gap: 0
# wandb: 	tree_method: None
# wandb: 	trg_look_ahead: 300
# wandb: 	trg_stop_loss: 5
# wandb: 	trg_take_profit: 35
# wandb: 	use_dynamic_sl: True
# Tracking run with wandb version 0.18.7
# Run data is saved locally in <code>/content/wandb/run-20241208_171308-aa5h708n</code>
# Syncing run <strong><a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/aa5h708n' target="_blank">light-sweep-1</a></strong> to <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>Sweep page: <a href='https://wandb.ai/alpha-hunters/algotrading-project/sweeps/hp6nl3b7' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/sweeps/hp6nl3b7</a>
#  View project at <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a>
#  View sweep at <a href='https://wandb.ai/alpha-hunters/algotrading-project/sweeps/hp6nl3b7' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/sweeps/hp6nl3b7</a>
#  View run at <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/aa5h708n' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/aa5h708n</a>
# Final Parameters of the Model: {'colsample_bytree': 0.5, 'device': 'cpu', 'early_stopping_rounds': None, 'learning_rate': 0.1, 'max_depth': 4, 'min_child_weight': 1, 'n_estimators': 100, 'objective': 'binary:logistic', 'random_state': 42, 'reg_lambda': 0, 'scale_pos_weight': 1, 'subsample': 0.3, 'tree_method': None}
# Dataset file not found at: /kaggle/working/ML-Algotrading-Project/dataset/data/dataset/dataset.parquet
# Len all columns in dataframe is 385
# Len read columns is 385
# Calculating target --->
# ---> Target trg_clf_long_EURUSD_M300_TP35_SL5 has been generated in 2.27 seconds
# df shape:  (143605, 386)
# ==============================
# --> df final shape: (143605, 385)
# --> df min_time: 2023-01-10 03:55:00 | df max_time: 2024-12-06 18:55:00
# --> number of unique days: 143605
# ==============================
# Fold 0:
# --> fold train size: (91765, 390)
# --> fold valid size: (8640, 390)
# --> fold test size: (8640, 390)
#   dataset  K  f1_score  precision  recall   TP  FP     TN    FN  \
# 0   train  0      0.32       0.95    0.19  639  35  88435  2656
# 1   valid  0      0.02       0.60    0.01    3   2   8397   238
# 2    test  0      0.00       0.00    0.00    0   0   8450   190
#
#              Min_date            Max_date train_duration  profit_percent  \
# 0 2023-01-10 03:55:00 2024-03-29 18:55:00           17.6             NaN
# 1 2024-03-29 19:00:00 2024-05-10 18:55:00           17.6           10.11
# 2 2024-05-10 19:00:00 2024-06-21 18:55:00           17.6            0.00
#
#    max_dd n_unique_days n_max_daily_sig
# 0     NaN          None            None
# 1   -0.53             2               3
# 2    0.00             0             NaN
# Fold 1:
# --> fold train size: (109045, 390)
# --> fold valid size: (8640, 390)
# --> fold test size: (8640, 390)
# wandb: Ctrl + C detected. Stopping sweep.
#  View run <strong style="color:#cdcd00">light-sweep-1</strong> at: <a href='https://wandb.ai/alpha-hunters/algotrading-project/runs/aa5h708n' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project/runs/aa5h708n</a><br/> View project at: <a href='https://wandb.ai/alpha-hunters/algotrading-project' target="_blank">https://wandb.ai/alpha-hunters/algotrading-project</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20241208_171308-aa5h708n/logs</code>
# CPU times: user 1min 4s, sys: 1.67 s, total: 1min 6s
# Wall time: 59.8 s

# %%
# Import necessary libraries
import wandb

# The sweep ID should be the same as the one you started with
sweep_id = 'hp6nl3b7'

# Resume the sweep
wandb.agent(sweep_id=sweep_id, function=main, entity='alpha-hunters', project='algotrading-project')

# Finish the sweep
wandb.finish()

# %%
#STOP SWEEP
if not MANUAL_EXP:
    print('Finishing The SWEEP ...')
    print(f'{1/0}')

# %% [markdown]
# # Filter models from W&B

# %%
runs_filter = {'path' : "fitechivo/tradeset_models",# /artifacts/experiment/trg_clf_long_EURUSD_M240_TP25_SL10
               "order": "+summary_metrics.profit_percent_test",
    'filters': {"$and": [
#                         {"state":'finished'},
                        {"createdAt":{ '$gte': '2024-06-01' }},
                        {"sweep":'jmw8zpy9'},

                        ########### GENERAL CONFIG #############
                        {"config.target_symbol":'USDJPY'},
                        {"config.trade_mode": 'long'},
#                         {"config.look_ahead": 480},
#                         {"config.strg_take_profit": 40},
#                         {"config.strg_stop_loss": 15},
                        {"config.model_name":'XGB'},
#                         ########### MODEL CONFIG #############
#                         {"config.max_depth": 3 },
#                         {"config.n_estimators": { "$gte": 100 } },
#                         {"config.learning_rate": { "$lt": 1 }},
#                         {"config.random_state": 42 },

                        ########### MODEL METRICS #############
                        {"summary_metrics.profit_percent_test" : { "$gte": 10}},
                        {"summary_metrics.profit_percent_val" : { "$gte": 10}},

                        {"summary_metrics.profit_percent_median_test" : { "$gte": 5}},
                        {"summary_metrics.profit_percent_median_valid" : { "$gte": 5}},

                        {"summary_metrics.max_dd_min_test" : { "$gte":-40}},
                        {"summary_metrics.max_dd_min_valid" : { "$gte":-40}},

                        {"summary_metrics.max_dd_test" : { "$gte":-40}},
                        {"summary_metrics.max_dd_val" : { "$gte":-40}},



                                ]
            }
}
runs=api.runs(**runs_filter)
print(len(runs))

# %%
# wandb.finish()

# %%
import shutil
import os
if os.path.isdir("/kaggle/working/artifacts"):
    shutil.rmtree("/kaggle/working/artifacts")
meta_datas=fetch_artifacts(runs_filter)

# %%
objects = read_tracker_objects("/kaggle/working/artifacts")

# %%
# objects['XGB_long_USDJPY_M300_TP35_SL5_prof531.41_max_dd-56.54_median_sig9.00_date2024-07-08_21:24']['obj'].evals

# %% [markdown]
# ## Selected Models' Config

# %%
import pandas as pd
for i,k in enumerate(objects):
    if i == 0:
        df_config = pd.DataFrame(objects[k]['obj'].config, index = [0])
#         display(df_config)
    else:
        df_config = pd.concat([df_config,pd.DataFrame(objects[k]['obj'].config, index = [0])])
# df_config[['colsample_bytree',
#        'learning_rate', 'trg_look_ahead', 'max_depth', 'max_train_size',
#        'min_child_weight', 'model_name', 'n_estimators', 'save_model_mode', 'scale_pos_weight',
#        'subsample', 'trg_take_profit', 'target_symbol', 'tree_method']]
df_config

# %% [markdown]
# ## Feature Importance

# %%
for i,k in enumerate(objects):
    if i == 0:
        df_imp = objects[k]['obj'].feature_importance
        df_imp.rename(columns = {'importances': f'importances_{i}'}, inplace =True)
    else:

        df_imp = df_imp.merge(objects[k]['obj'].feature_importance.rename(columns = {'importances': f'importances_{i}'}),
                             on = 'feature_name')
imp_cols = [f for f in df_imp.columns if 'importances_' in f]
df_imp['imp_mean'] =df_imp[imp_cols].mean(axis = 1)
df_imp.sort_values('imp_mean', ascending = False)[:30]

# %% [markdown]
# ## Models' Correlation

# %%
import pandas as pd
def cal_corr_tar1_predictions(objects):
    '''Calculate corrilation between models Just for target==1'''
    corr_ls=[]
    for i,n in enumerate(objects):

        val_predictions = objects[n]['obj'].val_predictions
        val_predictions=val_predictions[val_predictions.target==1][['pred_as_val','target']].replace(0, -1)
        corr_ls.append((n,val_predictions))
    print("Total_model_count:", len(corr_ls))

    from sklearn.metrics import matthews_corrcoef
    corr_dict={}
    for i in range(0,len(corr_ls)):
        for j in range(i+1,len(corr_ls)):
            corr_dict[(corr_ls[i][0],corr_ls[j][0])]=matthews_corrcoef(corr_ls[i][1]['pred_as_val'], corr_ls[j][1]['pred_as_val'])


    corr_df=pd.DataFrame([k + (v,) for k, v in corr_dict.items()], columns=['model1', 'model2', 'M_corr'])
    print('combination checked:', corr_df.shape[0])
    corr_df.hist('M_corr')
    return corr_df

corr_df=cal_corr_tar1_predictions(objects)

# %%
# corr_df[corr_df.M_corr<0.7]
corr_df
